# %% [markdown]
# # Climate Prediction Results

# %%
import pandas as pd
import os
import sys

# %%
# Add the folder to the Python path

os.chdir("../")
# change working directory to project's root path
print(os.getcwd())

folder_path = os.path.abspath("functions/") #INPUT_PATH)#'path_to_your_folder')  # Replace with the actual folder path
sys.path.insert(0, folder_path)

from Predictions import (
    get_info_experiment,
    summarize_best_results_by_index,
    plot_average_best_results,
    plot_best_results_per_season,
    PredictionExperiment
)
# Out:
# c:\Users\marti\Desktop\data\hw_extra
# c:\Users\marti\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
def train_single_label_exp(exp_id, season, label_interest, model_exp, name_model, region):
    labels_to_remove = ["HWN", "HWF", "HWD", "HWA", "HWM"]
    labels_to_remove.remove(label_interest)
    display(get_info_experiment(exp_id, metadata_exp_path=metadata_exp_path, metadata_index_path=my_indices_path, extra_indices_path=extra_indices_path))
    data = {season: pd.read_parquet(f"data/climate_features/{region}/predictor_{id}_{season}.parquet")}
    data[season].drop(columns=labels_to_remove, inplace=True)
    experiment_1 = PredictionExperiment(data, [label_interest], [model_exp], [name_model], 5, id)
    experiment_1.execute_experiment()
    experiment_1.get_metrics("r2", stage="TSCV", show=False)
    experiment_1.get_metrics("mape", stage="TSCV", show=False)
    display(experiment_1.results)
    return experiment_1

def display_full(df):
    with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.float_format', '{:,.2f}'.format):  # more options can be specified also
        display(df)

# %%
my_indices_path = "data/my_indices/metadata.csv"
extra_indices_path = "data/extra_indices/metadata.csv"

# %% [markdown]
# ## California

# %%
region = "california"
metadata_exp_path = f"data/climate_features/{region}/metadata.csv"
metadata = pd.read_csv(metadata_exp_path)
metadata.rename(columns={"id":"id_data"}, inplace=True)
metadata
# Out:
#      id_data                       filename  season
# 0   6e47cb06   predictor_6e47cb06_1.parquet       1  \
# 1   6e47cb06   predictor_6e47cb06_2.parquet       2
# 2   6e47cb06   predictor_6e47cb06_3.parquet       3
# 3   6e47cb06   predictor_6e47cb06_4.parquet       4
# 4   6e47cb06   predictor_6e47cb06_5.parquet       5
# 5   6e47cb06   predictor_6e47cb06_6.parquet       6
# 6   6e47cb06   predictor_6e47cb06_7.parquet       7
# 7   6e47cb06   predictor_6e47cb06_8.parquet       8
# 8   6e47cb06   predictor_6e47cb06_9.parquet       9
# 9   6e47cb06  predictor_6e47cb06_10.parquet      10
# 10  6e47cb06  predictor_6e47cb06_11.parquet      11
# 11  6e47cb06  predictor_6e47cb06_12.parquet      12
# 12  5cb3fa02   predictor_5cb3fa02_1.parquet       1
# 13  5cb3fa02   predictor_5cb3fa02_2.parquet       2
# 14  5cb3fa02   predictor_5cb3fa02_3.parquet       3
# 15  5cb3fa02   predictor_5cb3fa02_4.parquet       4
# 16  5cb3fa02   predictor_5cb3fa02_5.parquet       5
# 17  5cb3fa02   predictor_5cb3fa02_6.parquet       6
# 18  5cb3fa02   predictor_5cb3fa02_7.parquet       7
# 19  5cb3fa02   predictor_5cb3fa02_8.parquet       8
# 20  5cb3fa02   predictor_5cb3fa02_9.parquet       9
# 21  5cb3fa02  predictor_5cb3fa02_10.parquet      10
# 22  5cb3fa02  predictor_5cb3fa02_11.parquet      11
# 23  5cb3fa02  predictor_5cb3fa02_12.parquet      12
#
#                                               indices
# 0   df9a31c5-20a07cea-cfb03125-9169e0dc-0b0bffae-b...
# 1   df9a31c5-20a07cea-cfb03125-9169e0dc-0b0bffae-b...
# 2   df9a31c5-20a07cea-cfb03125-9169e0dc-0b0bffae-b...
# 3   df9a31c5-20a07cea-cfb03125-9169e0dc-0b0bffae-b...
# 4   df9a31c5-20a07cea-cfb03125-9169e0dc-0b0bffae-b...
# 5   df9a31c5-20a07cea-cfb03125-9169e0dc-0b0bffae-b...
# 6   df9a31c5-20a07cea-cfb03125-9169e0dc-0b0bffae-b...
# 7   df9a31c5-20a07cea-cfb03125-9169e0dc-0b0bffae-b...
# 8   df9a31c5-20a07cea-cfb03125-9169e0dc-0b0bffae-b...
# 9   df9a31c5-20a07cea-cfb03125-9169e0dc-0b0bffae-b...
# 10  df9a31c5-20a07cea-cfb03125-9169e0dc-0b0bffae-b...
# 11  df9a31c5-20a07cea-cfb03125-9169e0dc-0b0bffae-b...
# 12  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 13  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 14  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 15  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 16  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 17  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 18  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 19  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 20  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 21  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 22  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 23  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...

# %%
results = pd.read_csv(f"data/climate_results_NN/{region}_results/results.csv")
results
# Out:
#         model  season metric       stage       HWN       HWF       HWD
# 0       RNN16       1     r2  prediction  0.404952 -0.044195 -0.053677  \
# 1      LSTM16       1     r2  prediction -0.198438 -0.222593 -0.296213
# 2       GRU16       1     r2  prediction -0.237761 -0.238086 -0.385357
# 3      SRNN16       1     r2  prediction  0.087323  0.109975 -0.438949
# 4     SLSTM16       1     r2  prediction -0.141627 -0.197139 -0.299687
# ...       ...     ...    ...         ...       ...       ...       ...
# 3067   Linear       8    mae        TSCV  0.245990  1.003778  0.892195
# 3068   Linear       9    mae        TSCV  0.314457  1.688518  1.036244
# 3069   Linear      10    mae        TSCV  0.455515  2.486041  1.632246
# 3070   Linear      11    mae        TSCV  0.282616  1.231804  1.106450
# 3071   Linear      12    mae        TSCV  0.226056  1.059476  0.804613
#
#            HWM       HWA   Average   id_data
# 0     0.055344  0.309246  0.134334  6e47cb06
# 1    -0.385324 -0.259515 -0.272417  6e47cb06
# 2    -0.419552 -0.315618 -0.319275  6e47cb06
# 3     0.100229 -0.598095 -0.147903  6e47cb06
# 4    -0.358860 -0.337403 -0.266943  6e47cb06
# ...        ...       ...       ...       ...
# 3067  0.422024  0.681094  0.649016  5cb3fa02
# 3068  0.686407  1.143567  0.973839  5cb3fa02
# 3069  0.719400  1.301669  1.318974  5cb3fa02
# 3070  0.553996  0.889646  0.812902  5cb3fa02
# 3071  0.363637  0.654768  0.621710  5cb3fa02
#
# [3072 rows x 11 columns]

# %%
# Example usage
summary_r2 = summarize_best_results_by_index(results, metadata, metric="r2", top_n=2, stage="prediction")
summary_mape = summarize_best_results_by_index(results, metadata, metric="mape", top_n=2, stage="prediction")
summary_mae = summarize_best_results_by_index(results, metadata, metric="mae", top_n=2, stage="prediction")
summary_cv_r2 = summarize_best_results_by_index(results, metadata, metric="r2", top_n=2, stage="CV")
summary_cv_mape = summarize_best_results_by_index(results, metadata, metric="mape", top_n=2, stage="CV")
summary_cv_mae = summarize_best_results_by_index(results, metadata, metric="mae", top_n=2, stage="CV")
summary_tscv_r2 = summarize_best_results_by_index(results, metadata, metric="r2", top_n=2, stage="TSCV")
summary_tscv_mape = summarize_best_results_by_index(results, metadata, metric="mape", top_n=2, stage="TSCV")
summary_tscv_mae = summarize_best_results_by_index(results, metadata, metric="mae", top_n=2, stage="TSCV")

# %%
cv_r2_seasons = {}
cv_mape_seasons = {}
cv_mae_seasons = {}
r2_seasons = {}
mape_seasons = {}
tscv_r2_seasons = {}
tscv_mape_seasons = {}
for i in range(13):
    results_season = results[results["season"]==i]
    cv_r2_seasons[i] = summarize_best_results_by_index(results_season, metadata, metric="r2",stage="CV" , top_n=1)
    tscv_r2_seasons[i] = summarize_best_results_by_index(results_season, metadata, metric="r2",stage="TSCV" , top_n=1)
    r2_seasons[i] = summarize_best_results_by_index(results_season, metadata, metric="r2",stage="prediction", top_n=1)
    mape_seasons[i] = summarize_best_results_by_index(results_season, metadata, metric="mape",stage="prediction", top_n=1)
    cv_mape_seasons[i] = summarize_best_results_by_index(results_season, metadata, metric="mape",stage="CV", top_n=1)
    cv_mae_seasons[i] = summarize_best_results_by_index(results_season, metadata, metric="mae",stage="CV", top_n=1)
    tscv_mape_seasons[i] = summarize_best_results_by_index(results_season, metadata, metric="mape",stage="TSCV", top_n=1)

cv_r2_seasons = pd.concat(list(cv_r2_seasons.values()))
cv_mape_seasons = pd.concat(list(cv_mape_seasons.values()))
cv_mae_seasons = pd.concat(list(cv_mae_seasons.values()))
tscv_r2_seasons = pd.concat(list(tscv_r2_seasons.values()))
tscv_mape_seasons = pd.concat(list(tscv_mape_seasons.values()))
r2_seasons = pd.concat(list(r2_seasons.values()))
mape_seasons = pd.concat(list(mape_seasons.values()))

# %%
display_full(cv_mae_seasons)
# Out:
#        model    index  best_value   id_data                       filename
# 0       MLP8  Average        0.61  5cb3fa02   predictor_5cb3fa02_1.parquet  \
# 1       MLP8      HWA        0.63  5cb3fa02   predictor_5cb3fa02_1.parquet
# 2   CNNRNN16      HWD        0.45  5cb3fa02  predictor_5cb3fa02_12.parquet
# 3   CNNRNN16      HWF        0.42  5cb3fa02  predictor_5cb3fa02_12.parquet
# 4   CNNRNN16      HWM        0.52  5cb3fa02  predictor_5cb3fa02_12.parquet
# 5   CNNRNN16      HWN        0.46  5cb3fa02  predictor_5cb3fa02_12.parquet
#
#    season                                            indices
# 0       1  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 1       1  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 2       1  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 3       1  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 4       1  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 5       1  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 0       2  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 1       2  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 2       2  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 3       2  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 4       2  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 5       2  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 0       3  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 1       3  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 2       3  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 3       3  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 4       3  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 5       3  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 0       4  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 1       4  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 2       4  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 3       4  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 4       4  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 5       4  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 0       5  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 1       5  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 2       5  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 3       5  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 4       5  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 5       5  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 0       6  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 1       6  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 2       6  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 3       6  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 4       6  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 5       6  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 0       7  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 1       7  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 2       7  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 3       7  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 4       7  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 5       7  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 0       8  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 1       8  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 2       8  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 3       8  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 4       8  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 5       8  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 0       9  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 1       9  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 2       9  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 3       9  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 4       9  df9a31c5-20a07cea-cfb03125-9169e0dc-0b0bffae-b...
# 5       9  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 0      10  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 1      10  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 2      10  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 3      10  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 4      10  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 5      10  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 0      11  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 1      11  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 2      11  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 3      11  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 4      11  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 5      11  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 0      12  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 1      12  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 2      12  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 3      12  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 4      12  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 5      12  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...

# %% [markdown]
# ## Chile

# %%
region = "chile"
metadata_exp_path = f"data/climate_features/{region}/metadata.csv"
metadata = pd.read_csv(metadata_exp_path)
metadata.rename(columns={"id":"id_data"}, inplace=True)
metadata
# Out:
#       id_data                       filename  season
# 0    978f49d7   predictor_978f49d7_1.parquet       1  \
# 1    978f49d7   predictor_978f49d7_2.parquet       2
# 2    978f49d7   predictor_978f49d7_3.parquet       3
# 3    978f49d7   predictor_978f49d7_4.parquet       4
# 4    978f49d7   predictor_978f49d7_5.parquet       5
# ..        ...                            ...     ...
# 247  458d357c   predictor_458d357c_8.parquet       8
# 248  458d357c   predictor_458d357c_9.parquet       9
# 249  458d357c  predictor_458d357c_10.parquet      10
# 250  458d357c  predictor_458d357c_11.parquet      11
# 251  458d357c  predictor_458d357c_12.parquet      12
#
#                                                indices
# 0    fde0e327-340e2882-43701738-e306f58b-e601b072-e...
# 1    fde0e327-340e2882-43701738-e306f58b-e601b072-e...
# 2    fde0e327-340e2882-43701738-e306f58b-e601b072-e...
# 3    fde0e327-340e2882-43701738-e306f58b-e601b072-e...
# 4    fde0e327-340e2882-43701738-e306f58b-e601b072-e...
# ..                                                 ...
# 247  32f131d2-69ffcfa8-4af95abb-4a86cb22-52eda853-3...
# 248  32f131d2-69ffcfa8-4af95abb-4a86cb22-52eda853-3...
# 249  32f131d2-69ffcfa8-4af95abb-4a86cb22-52eda853-3...
# 250  32f131d2-69ffcfa8-4af95abb-4a86cb22-52eda853-3...
# 251  32f131d2-69ffcfa8-4af95abb-4a86cb22-52eda853-3...
#
# [252 rows x 4 columns]

# %%
results = pd.read_csv(f"data/climate_results_NN/{region}_results/results.csv")
results
# Out:
#          model  season metric       stage       HWN       HWF       HWD
# 0        RNN16       1     r2  prediction -1.137981 -0.101467 -0.540862  \
# 1       LSTM16       1     r2  prediction -0.296615 -0.293727 -0.611602
# 2        GRU16       1     r2  prediction -0.451169 -0.875157 -0.520603
# 3       SRNN16       1     r2  prediction -1.121952 -0.590102  0.306276
# 4      SLSTM16       1     r2  prediction -0.134914 -0.415837 -0.338187
# ...        ...     ...    ...         ...       ...       ...       ...
# 32251   Linear       8    mae        TSCV  0.378467  1.550969  1.094913
# 32252   Linear       9    mae        TSCV  0.262776  1.020800  0.861764
# 32253   Linear      10    mae        TSCV  0.240909  0.892987  0.765239
# 32254   Linear      11    mae        TSCV  0.198708  0.670160  0.521324
# 32255   Linear      12    mae        TSCV  0.160910  0.649017  0.606395
#
#             HWM       HWA   Average   id_data
# 0      0.004724 -1.245405 -0.604198  978f49d7
# 1     -0.136574  0.003455 -0.267013  978f49d7
# 2     -0.549754 -0.113211 -0.501979  978f49d7
# 3     -0.561515 -1.116073 -0.616674  978f49d7
# 4      0.019838 -0.104378 -0.194695  978f49d7
# ...         ...       ...       ...       ...
# 32251  0.762787  1.455566  1.048540  458d357c
# 32252  0.635964  1.014843  0.759230  458d357c
# 32253  0.515215  0.889996  0.660869  458d357c
# 32254  0.291885  0.598814  0.456178  458d357c
# 32255  0.301150  0.549015  0.453297  458d357c
#
# [32256 rows x 11 columns]

# %%
# Example usage
summary_r2 = summarize_best_results_by_index(results, metadata, metric="r2", top_n=2, stage="prediction")
summary_mape = summarize_best_results_by_index(results, metadata, metric="mape", top_n=2, stage="prediction")
summary_mae = summarize_best_results_by_index(results, metadata, metric="mae", top_n=2, stage="prediction")
summary_cv_r2 = summarize_best_results_by_index(results, metadata, metric="r2", top_n=2, stage="CV")
summary_cv_mape = summarize_best_results_by_index(results, metadata, metric="mape", top_n=2, stage="CV")
summary_cv_mae = summarize_best_results_by_index(results, metadata, metric="mae", top_n=2, stage="CV")
summary_tscv_r2 = summarize_best_results_by_index(results, metadata, metric="r2", top_n=2, stage="TSCV")
summary_tscv_mape = summarize_best_results_by_index(results, metadata, metric="mape", top_n=2, stage="TSCV")
summary_tscv_mae = summarize_best_results_by_index(results, metadata, metric="mae", top_n=2, stage="TSCV")

# %%
display_full(summary_mae)
# Out:
# Empty DataFrame
# Columns: [best_value, model, index, training_value, id_data, filename, season, indices]
# Index: []

# %%
cv_r2_seasons = {}
cv_mape_seasons = {}
cv_mae_seasons = {}
r2_seasons = {}
mape_seasons = {}
tscv_r2_seasons = {}
tscv_mape_seasons = {}
tscv_mae_seasons = {}

for i in range(13):
    results_season = results[results["season"]==i]
    cv_r2_seasons[i] = summarize_best_results_by_index(results_season, metadata, metric="r2",stage="CV" , top_n=1)
    tscv_r2_seasons[i] = summarize_best_results_by_index(results_season, metadata, metric="r2",stage="TSCV" , top_n=1)
    r2_seasons[i] = summarize_best_results_by_index(results_season, metadata, metric="r2",stage="prediction", top_n=1)
    mape_seasons[i] = summarize_best_results_by_index(results_season, metadata, metric="mape",stage="prediction", top_n=1)
    cv_mape_seasons[i] = summarize_best_results_by_index(results_season, metadata, metric="mape",stage="CV", top_n=1)
    cv_mae_seasons[i] = summarize_best_results_by_index(results_season, metadata, metric="mae",stage="CV", top_n=1)
    tscv_mape_seasons[i] = summarize_best_results_by_index(results_season, metadata, metric="mape",stage="TSCV", top_n=1)
    tscv_mae_seasons[i] = summarize_best_results_by_index(results_season, metadata, metric="mape",stage="TSCV", top_n=1)

cv_r2_seasons = pd.concat(list(cv_r2_seasons.values()))
cv_mape_seasons = pd.concat(list(cv_mape_seasons.values()))
cv_mae_seasons = pd.concat(list(cv_mae_seasons.values()))
tscv_r2_seasons = pd.concat(list(tscv_r2_seasons.values()))
tscv_mape_seasons = pd.concat(list(tscv_mape_seasons.values()))
tscv_mae_seasons = pd.concat(list(tscv_mae_seasons.values()))

r2_seasons = pd.concat(list(r2_seasons.values()))
mape_seasons = pd.concat(list(mape_seasons.values()))

# %%
df = cv_mae_seasons
display_full(df[df["best_value"] > 0])
# display_full(df)
# Out:
#        model    index  best_value   id_data                       filename
# 0   CNNRNN16  Average        0.58  ecf2577f   predictor_ecf2577f_1.parquet  \
# 1   CNNRNN16      HWA        0.57  ecf2577f   predictor_ecf2577f_1.parquet
# 2   CNNRNN16      HWD        0.60  ecf2577f   predictor_ecf2577f_1.parquet
# 3      LSTM8      HWF        0.57  458d357c   predictor_458d357c_1.parquet
# 4      MLP16      HWM        0.56  978f49d7   predictor_978f49d7_1.parquet
# 5   CNNRNN16      HWN        0.57  ecf2577f   predictor_ecf2577f_1.parquet
# 0  CNNLSTM16  Average        0.55  9bd58418   predictor_9bd58418_2.parquet
# 1       RNN8      HWA        0.48  30ab9bad   predictor_30ab9bad_2.parquet
# 2       MLP8      HWD        0.58  8c95fd00   predictor_8c95fd00_2.parquet
# 3  CNNLSTM16      HWF        0.56  9bd58418   predictor_9bd58418_2.parquet
# 4       RNN8      HWM        0.50  30ab9bad   predictor_30ab9bad_2.parquet
# 5  CNNLSTM16      HWN        0.51  9bd58418   predictor_9bd58418_2.parquet
# 0       RNN8  Average        0.54  458d357c   predictor_458d357c_3.parquet
# 1       RNN8      HWA        0.54  458d357c   predictor_458d357c_3.parquet
# 2       RNN8      HWD        0.50  458d357c   predictor_458d357c_3.parquet
# 3      MLP16      HWF        0.49  8359c65d   predictor_8359c65d_3.parquet
# 4   CNNRNN16      HWM        0.55  9f8163e4   predictor_9f8163e4_3.parquet
# 5       RNN8      HWN        0.52  458d357c   predictor_458d357c_3.parquet
# 0   CNNRNN16  Average        0.55  d7101242   predictor_d7101242_4.parquet
# 1      MLP16      HWA        0.53  30ab9bad   predictor_30ab9bad_4.parquet
# 2      MLP16      HWD        0.55  30ab9bad   predictor_30ab9bad_4.parquet
# 3   CNNRNN16      HWF        0.53  30ab9bad   predictor_30ab9bad_4.parquet
# 4   CNNRNN16      HWM        0.54  d7101242   predictor_d7101242_4.parquet
# 5      MLP16      HWN        0.54  30ab9bad   predictor_30ab9bad_4.parquet
# 0   CNNRNN16  Average        0.47  ecf2577f   predictor_ecf2577f_5.parquet
# 1   CNNRNN16      HWA        0.45  ecf2577f   predictor_ecf2577f_5.parquet
# 2   CNNRNN16      HWD        0.49  311dd366   predictor_311dd366_5.parquet
# 3      MLP16      HWF        0.45  9f8163e4   predictor_9f8163e4_5.parquet
# 4   CNNRNN16      HWM        0.48  ecf2577f   predictor_ecf2577f_5.parquet
# 5   CNNRNN16      HWN        0.44  ecf2577f   predictor_ecf2577f_5.parquet
# 0      MLP16  Average        0.50  3df87a13   predictor_3df87a13_6.parquet
# 1   CNNRNN16      HWA        0.51  311dd366   predictor_311dd366_6.parquet
# 2       RNN8      HWD        0.50  458d357c   predictor_458d357c_6.parquet
# 3      MLP16      HWF        0.48  3df87a13   predictor_3df87a13_6.parquet
# 4       RNN8      HWM        0.50  458d357c   predictor_458d357c_6.parquet
# 5      MLP16      HWN        0.46  3df87a13   predictor_3df87a13_6.parquet
# 0      MLP16  Average        0.47  d7101242   predictor_d7101242_7.parquet
# 1      MLP16      HWA        0.48  d7101242   predictor_d7101242_7.parquet
# 2      MLP16      HWD        0.49  d7101242   predictor_d7101242_7.parquet
# 3      MLP16      HWF        0.44  d7101242   predictor_d7101242_7.parquet
# 4      MLP16      HWM        0.46  d7101242   predictor_d7101242_7.parquet
# 5      MLP16      HWN        0.48  d7101242   predictor_d7101242_7.parquet
# 0       MLP8  Average        0.58  9f8163e4   predictor_9f8163e4_8.parquet
# 1       MLP8      HWA        0.56  9f8163e4   predictor_9f8163e4_8.parquet
# 2  CNNLSTM16      HWD        0.55  511854f2   predictor_511854f2_8.parquet
# 3   CNNRNN16      HWF        0.53  8c95fd00   predictor_8c95fd00_8.parquet
# 4  CNNLSTM16      HWM        0.59  30ab9bad   predictor_30ab9bad_8.parquet
# 5  CNNLSTM16      HWN        0.51  1b939ac5   predictor_1b939ac5_8.parquet
# 0       MLP8  Average        0.58  311dd366   predictor_311dd366_9.parquet
# 1       MLP8      HWA        0.55  458d357c   predictor_458d357c_9.parquet
# 2      MLP16      HWD        0.59  3832cbd6   predictor_3832cbd6_9.parquet
# 3       MLP8      HWF        0.50  311dd366   predictor_311dd366_9.parquet
# 4       MLP8      HWM        0.61  458d357c   predictor_458d357c_9.parquet
# 5       MLP8      HWN        0.56  9f8163e4   predictor_9f8163e4_9.parquet
# 0   CNNRNN16  Average        0.53  30ab9bad  predictor_30ab9bad_10.parquet
# 1      LSTM8      HWA        0.51  8c95fd00  predictor_8c95fd00_10.parquet
# 2       RNN8      HWD        0.54  458d357c  predictor_458d357c_10.parquet
# 3   CNNRNN16      HWF        0.52  30ab9bad  predictor_30ab9bad_10.parquet
# 4      LSTM8      HWM        0.53  8c95fd00  predictor_8c95fd00_10.parquet
# 5   CNNRNN16      HWN        0.53  30ab9bad  predictor_30ab9bad_10.parquet
# 0       RNN8  Average        0.48  30ab9bad  predictor_30ab9bad_11.parquet
# 1       RNN8      HWA        0.50  30ab9bad  predictor_30ab9bad_11.parquet
# 2       RNN8      HWD        0.47  30ab9bad  predictor_30ab9bad_11.parquet
# 3   CNNRNN16      HWF        0.42  8c95fd00  predictor_8c95fd00_11.parquet
# 4       RNN8      HWM        0.49  458d357c  predictor_458d357c_11.parquet
# 5   CNNRNN16      HWN        0.44  8c95fd00  predictor_8c95fd00_11.parquet
# 0       RNN8  Average        0.38  458d357c  predictor_458d357c_12.parquet
# 1       RNN8      HWA        0.39  458d357c  predictor_458d357c_12.parquet
# 2       RNN8      HWD        0.39  458d357c  predictor_458d357c_12.parquet
# 3       RNN8      HWF        0.35  458d357c  predictor_458d357c_12.parquet
# 4   CNNRNN16      HWM        0.39  311dd366  predictor_311dd366_12.parquet
# 5   CNNRNN16      HWN        0.37  9f8163e4  predictor_9f8163e4_12.parquet
#
#    season                                            indices
# 0       1  1f3bbd82-aac61eb2-bf935817-80ce3764-d6188e35-7...
# 1       1  1f3bbd82-aac61eb2-bf935817-80ce3764-d6188e35-7...
# 2       1  1f3bbd82-aac61eb2-bf935817-80ce3764-d6188e35-7...
# 3       1  32f131d2-69ffcfa8-4af95abb-4a86cb22-52eda853-3...
# 4       1  fde0e327-340e2882-43701738-e306f58b-e601b072-e...
# 5       1  1f3bbd82-aac61eb2-bf935817-80ce3764-d6188e35-7...
# 0       2  fde0e327-340e2882-b91ccd4e-c6184040-c1c59e4d-8...
# 1       2  fde0e327-340e2882-880b8b63-aa75d48e-88249a81-f...
# 2       2  fde0e327-340e2882-8c5bce37-880b8b63-aa75d48e-8...
# 3       2  fde0e327-340e2882-b91ccd4e-c6184040-c1c59e4d-8...
# 4       2  fde0e327-340e2882-880b8b63-aa75d48e-88249a81-f...
# 5       2  fde0e327-340e2882-b91ccd4e-c6184040-c1c59e4d-8...
# 0       3  32f131d2-69ffcfa8-4af95abb-4a86cb22-52eda853-3...
# 1       3  32f131d2-69ffcfa8-4af95abb-4a86cb22-52eda853-3...
# 2       3  32f131d2-69ffcfa8-4af95abb-4a86cb22-52eda853-3...
# 3       3  422ed1de-59f835e4-c1c59e4d-03244181-1223f1f4-7...
# 4       3  fde0e327-340e2882-8c5bce37-880b8b63-c6b80290-3...
# 5       3  32f131d2-69ffcfa8-4af95abb-4a86cb22-52eda853-3...
# 0       4  fde0e327-340e2882-13e2f761-aa75d48e-2748fd3a-f...
# 1       4  fde0e327-340e2882-880b8b63-aa75d48e-88249a81-f...
# 2       4  fde0e327-340e2882-880b8b63-aa75d48e-88249a81-f...
# 3       4  fde0e327-340e2882-880b8b63-aa75d48e-88249a81-f...
# 4       4  fde0e327-340e2882-13e2f761-aa75d48e-2748fd3a-f...
# 5       4  fde0e327-340e2882-880b8b63-aa75d48e-88249a81-f...
# 0       5  1f3bbd82-aac61eb2-bf935817-80ce3764-d6188e35-7...
# 1       5  1f3bbd82-aac61eb2-bf935817-80ce3764-d6188e35-7...
# 2       5  fde0e327-340e2882-8c5bce37-880b8b63-aa75d48e-8...
# 3       5  fde0e327-340e2882-8c5bce37-880b8b63-c6b80290-3...
# 4       5  1f3bbd82-aac61eb2-bf935817-80ce3764-d6188e35-7...
# 5       5  1f3bbd82-aac61eb2-bf935817-80ce3764-d6188e35-7...
# 0       6  fde0e327-340e2882-880b8b63-aa75d48e-88249a81-f...
# 1       6  fde0e327-340e2882-8c5bce37-880b8b63-aa75d48e-8...
# 2       6  32f131d2-69ffcfa8-4af95abb-4a86cb22-52eda853-3...
# 3       6  fde0e327-340e2882-880b8b63-aa75d48e-88249a81-f...
# 4       6  32f131d2-69ffcfa8-4af95abb-4a86cb22-52eda853-3...
# 5       6  fde0e327-340e2882-880b8b63-aa75d48e-88249a81-f...
# 0       7  fde0e327-340e2882-13e2f761-aa75d48e-2748fd3a-f...
# 1       7  fde0e327-340e2882-13e2f761-aa75d48e-2748fd3a-f...
# 2       7  fde0e327-340e2882-13e2f761-aa75d48e-2748fd3a-f...
# 3       7  fde0e327-340e2882-13e2f761-aa75d48e-2748fd3a-f...
# 4       7  fde0e327-340e2882-13e2f761-aa75d48e-2748fd3a-f...
# 5       7  fde0e327-340e2882-13e2f761-aa75d48e-2748fd3a-f...
# 0       8  fde0e327-340e2882-8c5bce37-880b8b63-c6b80290-3...
# 1       8  fde0e327-340e2882-8c5bce37-880b8b63-c6b80290-3...
# 2       8  fde0e327-340e2882-b91ccd4e-c6184040-c1c59e4d-8...
# 3       8  fde0e327-340e2882-8c5bce37-880b8b63-aa75d48e-8...
# 4       8  fde0e327-340e2882-880b8b63-aa75d48e-88249a81-f...
# 5       8  fde0e327-340e2882-b91ccd4e-c6184040-c1c59e4d-8...
# 0       9  fde0e327-340e2882-8c5bce37-880b8b63-aa75d48e-8...
# 1       9  32f131d2-69ffcfa8-4af95abb-4a86cb22-52eda853-3...
# 2       9  fde0e327-340e2882-13e2f761-aa75d48e-2748fd3a-f...
# 3       9  fde0e327-340e2882-8c5bce37-880b8b63-aa75d48e-8...
# 4       9  32f131d2-69ffcfa8-4af95abb-4a86cb22-52eda853-3...
# 5       9  fde0e327-340e2882-8c5bce37-880b8b63-c6b80290-3...
# 0      10  fde0e327-340e2882-880b8b63-aa75d48e-88249a81-f...
# 1      10  fde0e327-340e2882-8c5bce37-880b8b63-aa75d48e-8...
# 2      10  32f131d2-69ffcfa8-4af95abb-4a86cb22-52eda853-3...
# 3      10  fde0e327-340e2882-880b8b63-aa75d48e-88249a81-f...
# 4      10  fde0e327-340e2882-8c5bce37-880b8b63-aa75d48e-8...
# 5      10  fde0e327-340e2882-880b8b63-aa75d48e-88249a81-f...
# 0      11  fde0e327-340e2882-880b8b63-aa75d48e-88249a81-f...
# 1      11  fde0e327-340e2882-880b8b63-aa75d48e-88249a81-f...
# 2      11  fde0e327-340e2882-880b8b63-aa75d48e-88249a81-f...
# 3      11  fde0e327-340e2882-8c5bce37-880b8b63-aa75d48e-8...
# 4      11  32f131d2-69ffcfa8-4af95abb-4a86cb22-52eda853-3...
# 5      11  fde0e327-340e2882-8c5bce37-880b8b63-aa75d48e-8...
# 0      12  32f131d2-69ffcfa8-4af95abb-4a86cb22-52eda853-3...
# 1      12  32f131d2-69ffcfa8-4af95abb-4a86cb22-52eda853-3...
# 2      12  32f131d2-69ffcfa8-4af95abb-4a86cb22-52eda853-3...
# 3      12  32f131d2-69ffcfa8-4af95abb-4a86cb22-52eda853-3...
# 4      12  fde0e327-340e2882-8c5bce37-880b8b63-aa75d48e-8...
# 5      12  fde0e327-340e2882-8c5bce37-880b8b63-c6b80290-3...

# %%
df = cv_mae_seasons
display_full(df[["model", "index", "best_value", "id_data", "season"]])
# display_full(df)
# Out:
#        model    index  best_value   id_data  season
# 0   CNNRNN16  Average        0.58  ecf2577f       1
# 1   CNNRNN16      HWA        0.57  ecf2577f       1
# 2   CNNRNN16      HWD        0.60  ecf2577f       1
# 3      LSTM8      HWF        0.57  458d357c       1
# 4      MLP16      HWM        0.56  978f49d7       1
# 5   CNNRNN16      HWN        0.57  ecf2577f       1
# 0  CNNLSTM16  Average        0.55  9bd58418       2
# 1       RNN8      HWA        0.48  30ab9bad       2
# 2       MLP8      HWD        0.58  8c95fd00       2
# 3  CNNLSTM16      HWF        0.56  9bd58418       2
# 4       RNN8      HWM        0.50  30ab9bad       2
# 5  CNNLSTM16      HWN        0.51  9bd58418       2
# 0       RNN8  Average        0.54  458d357c       3
# 1       RNN8      HWA        0.54  458d357c       3
# 2       RNN8      HWD        0.50  458d357c       3
# 3      MLP16      HWF        0.49  8359c65d       3
# 4   CNNRNN16      HWM        0.55  9f8163e4       3
# 5       RNN8      HWN        0.52  458d357c       3
# 0   CNNRNN16  Average        0.55  d7101242       4
# 1      MLP16      HWA        0.53  30ab9bad       4
# 2      MLP16      HWD        0.55  30ab9bad       4
# 3   CNNRNN16      HWF        0.53  30ab9bad       4
# 4   CNNRNN16      HWM        0.54  d7101242       4
# 5      MLP16      HWN        0.54  30ab9bad       4
# 0   CNNRNN16  Average        0.47  ecf2577f       5
# 1   CNNRNN16      HWA        0.45  ecf2577f       5
# 2   CNNRNN16      HWD        0.49  311dd366       5
# 3      MLP16      HWF        0.45  9f8163e4       5
# 4   CNNRNN16      HWM        0.48  ecf2577f       5
# 5   CNNRNN16      HWN        0.44  ecf2577f       5
# 0      MLP16  Average        0.50  3df87a13       6
# 1   CNNRNN16      HWA        0.51  311dd366       6
# 2       RNN8      HWD        0.50  458d357c       6
# 3      MLP16      HWF        0.48  3df87a13       6
# 4       RNN8      HWM        0.50  458d357c       6
# 5      MLP16      HWN        0.46  3df87a13       6
# 0      MLP16  Average        0.47  d7101242       7
# 1      MLP16      HWA        0.48  d7101242       7
# 2      MLP16      HWD        0.49  d7101242       7
# 3      MLP16      HWF        0.44  d7101242       7
# 4      MLP16      HWM        0.46  d7101242       7
# 5      MLP16      HWN        0.48  d7101242       7
# 0       MLP8  Average        0.58  9f8163e4       8
# 1       MLP8      HWA        0.56  9f8163e4       8
# 2  CNNLSTM16      HWD        0.55  511854f2       8
# 3   CNNRNN16      HWF        0.53  8c95fd00       8
# 4  CNNLSTM16      HWM        0.59  30ab9bad       8
# 5  CNNLSTM16      HWN        0.51  1b939ac5       8
# 0       MLP8  Average        0.58  311dd366       9
# 1       MLP8      HWA        0.55  458d357c       9
# 2      MLP16      HWD        0.59  3832cbd6       9
# 3       MLP8      HWF        0.50  311dd366       9
# 4       MLP8      HWM        0.61  458d357c       9
# 5       MLP8      HWN        0.56  9f8163e4       9
# 0   CNNRNN16  Average        0.53  30ab9bad      10
# 1      LSTM8      HWA        0.51  8c95fd00      10
# 2       RNN8      HWD        0.54  458d357c      10
# 3   CNNRNN16      HWF        0.52  30ab9bad      10
# 4      LSTM8      HWM        0.53  8c95fd00      10
# 5   CNNRNN16      HWN        0.53  30ab9bad      10
# 0       RNN8  Average        0.48  30ab9bad      11
# 1       RNN8      HWA        0.50  30ab9bad      11
# 2       RNN8      HWD        0.47  30ab9bad      11
# 3   CNNRNN16      HWF        0.42  8c95fd00      11
# 4       RNN8      HWM        0.49  458d357c      11
# 5   CNNRNN16      HWN        0.44  8c95fd00      11
# 0       RNN8  Average        0.38  458d357c      12
# 1       RNN8      HWA        0.39  458d357c      12
# 2       RNN8      HWD        0.39  458d357c      12
# 3       RNN8      HWF        0.35  458d357c      12
# 4   CNNRNN16      HWM        0.39  311dd366      12
# 5   CNNRNN16      HWN        0.37  9f8163e4      12
