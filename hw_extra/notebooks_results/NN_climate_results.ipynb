# %% [markdown]
# # Climate Prediction Results

# %%
import pandas as pd
import os
import sys
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %%
# Add the folder to the Python path

os.chdir("../")
# change working directory to project's root path
print(os.getcwd())

folder_path = os.path.abspath("functions/") #INPUT_PATH)#'path_to_your_folder')  # Replace with the actual folder path
sys.path.insert(0, folder_path)

from Predictions import (
    get_info_experiment,
    summarize_best_results_by_index,
    plot_average_best_results,
    plot_best_results_per_season,
    PredictionExperiment
)
# Out:
# c:\Users\marti\Desktop\data\hw_extra
# c:\Users\marti\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
def train_single_label_exp(exp_id, season, label_interest, model_exp, name_model, region):
    labels_to_remove = ["HWN", "HWF", "HWD", "HWA", "HWM"]
    labels_to_remove.remove(label_interest)
    display(get_info_experiment(exp_id, metadata_exp_path=metadata_exp_path, metadata_index_path=my_indices_path, extra_indices_path=extra_indices_path))
    data = {season: pd.read_parquet(f"data/climate_features/{region}/predictor_{id}_{season}.parquet")}
    data[season].drop(columns=labels_to_remove, inplace=True)
    experiment_1 = PredictionExperiment(data, [label_interest], [model_exp], [name_model], 5, id)
    experiment_1.execute_experiment()
    experiment_1.get_metrics("r2", stage="TSCV", show=False)
    experiment_1.get_metrics("mape", stage="TSCV", show=False)
    display(experiment_1.results)
    return experiment_1

def display_full(df):
    with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.float_format', '{:,.2f}'.format):  # more options can be specified also
        display(df)

# %%
my_indices_path = "data/my_indices/metadata.csv"
extra_indices_path = "data/extra_indices/metadata.csv"

# %% [markdown]
# ## California

# %%
region = "california"
metadata_exp_path = f"data/climate_features/{region}/metadata.csv"
metadata = pd.read_csv(metadata_exp_path)
metadata.rename(columns={"id":"id_data"}, inplace=True)
metadata
# Out:
#      id_data                       filename  season
# 0   6e47cb06   predictor_6e47cb06_1.parquet       1  \
# 1   6e47cb06   predictor_6e47cb06_2.parquet       2
# 2   6e47cb06   predictor_6e47cb06_3.parquet       3
# 3   6e47cb06   predictor_6e47cb06_4.parquet       4
# 4   6e47cb06   predictor_6e47cb06_5.parquet       5
# 5   6e47cb06   predictor_6e47cb06_6.parquet       6
# 6   6e47cb06   predictor_6e47cb06_7.parquet       7
# 7   6e47cb06   predictor_6e47cb06_8.parquet       8
# 8   6e47cb06   predictor_6e47cb06_9.parquet       9
# 9   6e47cb06  predictor_6e47cb06_10.parquet      10
# 10  6e47cb06  predictor_6e47cb06_11.parquet      11
# 11  6e47cb06  predictor_6e47cb06_12.parquet      12
# 12  5cb3fa02   predictor_5cb3fa02_1.parquet       1
# 13  5cb3fa02   predictor_5cb3fa02_2.parquet       2
# 14  5cb3fa02   predictor_5cb3fa02_3.parquet       3
# 15  5cb3fa02   predictor_5cb3fa02_4.parquet       4
# 16  5cb3fa02   predictor_5cb3fa02_5.parquet       5
# 17  5cb3fa02   predictor_5cb3fa02_6.parquet       6
# 18  5cb3fa02   predictor_5cb3fa02_7.parquet       7
# 19  5cb3fa02   predictor_5cb3fa02_8.parquet       8
# 20  5cb3fa02   predictor_5cb3fa02_9.parquet       9
# 21  5cb3fa02  predictor_5cb3fa02_10.parquet      10
# 22  5cb3fa02  predictor_5cb3fa02_11.parquet      11
# 23  5cb3fa02  predictor_5cb3fa02_12.parquet      12
#
#                                               indices
# 0   df9a31c5-20a07cea-cfb03125-9169e0dc-0b0bffae-b...
# 1   df9a31c5-20a07cea-cfb03125-9169e0dc-0b0bffae-b...
# 2   df9a31c5-20a07cea-cfb03125-9169e0dc-0b0bffae-b...
# 3   df9a31c5-20a07cea-cfb03125-9169e0dc-0b0bffae-b...
# 4   df9a31c5-20a07cea-cfb03125-9169e0dc-0b0bffae-b...
# 5   df9a31c5-20a07cea-cfb03125-9169e0dc-0b0bffae-b...
# 6   df9a31c5-20a07cea-cfb03125-9169e0dc-0b0bffae-b...
# 7   df9a31c5-20a07cea-cfb03125-9169e0dc-0b0bffae-b...
# 8   df9a31c5-20a07cea-cfb03125-9169e0dc-0b0bffae-b...
# 9   df9a31c5-20a07cea-cfb03125-9169e0dc-0b0bffae-b...
# 10  df9a31c5-20a07cea-cfb03125-9169e0dc-0b0bffae-b...
# 11  df9a31c5-20a07cea-cfb03125-9169e0dc-0b0bffae-b...
# 12  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 13  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 14  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 15  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 16  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 17  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 18  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 19  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 20  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 21  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 22  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 23  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...

# %%
results = pd.read_csv(f"data/climate_results_NN/{region}_results/results.csv")
results
# Out:
#           model  season metric       stage       HWN       HWF       HWD
# 0         RNN16       1     r2  prediction  0.404952 -0.044195 -0.053677  \
# 1        LSTM16       1     r2  prediction -0.198438 -0.222593 -0.296213
# 2         GRU16       1     r2  prediction -0.237761 -0.238086 -0.385357
# 3        SRNN16       1     r2  prediction  0.087323  0.109975 -0.438949
# 4       SLSTM16       1     r2  prediction -0.141627 -0.197139 -0.299687
# ...         ...     ...    ...         ...       ...       ...       ...
# 1339     SRNN16      12    mae        TSCV  0.502856  0.480650  0.514638
# 1340    SLSTM16      12    mae        TSCV  0.465773  0.437876  0.471648
# 1341   CNNRNN16      12    mae        TSCV  0.572167  0.465668  0.647416
# 1342  CNNLSTM16      12    mae        TSCV  0.522929  0.534274  0.558769
# 1343      MLP16      12    mae        TSCV  0.588960  0.567265  0.521557
#
#            HWM       HWA   Average   id_data
# 0     0.055344  0.309246  0.134334  6e47cb06
# 1    -0.385324 -0.259515 -0.272417  6e47cb06
# 2    -0.419552 -0.315618 -0.319275  6e47cb06
# 3     0.100229 -0.598095 -0.147903  6e47cb06
# 4    -0.358860 -0.337403 -0.266943  6e47cb06
# ...        ...       ...       ...       ...
# 1339  0.551198  0.524057  0.514679  5cb3fa02
# 1340  0.472722  0.448999  0.459404  5cb3fa02
# 1341  0.447689  0.474824  0.521553  5cb3fa02
# 1342  0.565681  0.520581  0.540447  5cb3fa02
# 1343  0.545582  0.685877  0.581848  5cb3fa02
#
# [1344 rows x 11 columns]

# %%
# Example usage
summary_r2 = summarize_best_results_by_index(results, metadata, metric="r2", top_n=2, stage="prediction")
summary_mape = summarize_best_results_by_index(results, metadata, metric="mape", top_n=2, stage="prediction")
summary_cv_r2 = summarize_best_results_by_index(results, metadata, metric="r2", top_n=2, stage="CV")
summary_cv_mape = summarize_best_results_by_index(results, metadata, metric="mape", top_n=2, stage="CV")
summary_tscv_r2 = summarize_best_results_by_index(results, metadata, metric="r2", top_n=2, stage="TSCV")
summary_tscv_mape = summarize_best_results_by_index(results, metadata, metric="mape", top_n=2, stage="TSCV")

# %%
summary_tscv_r2
# Out:
#        model  season   id_data    index  best_value
# 0     LSTM16       5  5cb3fa02  Average    0.292254  \
# 1    SLSTM16       5  5cb3fa02  Average    0.262230
# 2    SLSTM16       5  5cb3fa02      HWA    0.300827
# 3      RNN16       5  5cb3fa02      HWA    0.300642
# 4     LSTM16       5  5cb3fa02      HWD    0.379829
# 5     SRNN16      10  5cb3fa02      HWD    0.335776
# 6     LSTM16       5  5cb3fa02      HWF    0.365055
# 7      MLP16      10  5cb3fa02      HWF    0.296915
# 8    SLSTM16       5  5cb3fa02      HWM    0.304191
# 9     LSTM16       2  5cb3fa02      HWM    0.298410
# 10     GRU16       5  5cb3fa02      HWN    0.363052
# 11  CNNRNN16       1  5cb3fa02      HWN    0.300202
#
#                          filename
# 0    predictor_5cb3fa02_5.parquet  \
# 1    predictor_5cb3fa02_5.parquet
# 2    predictor_5cb3fa02_5.parquet
# 3    predictor_5cb3fa02_5.parquet
# 4    predictor_5cb3fa02_5.parquet
# 5   predictor_5cb3fa02_10.parquet
# 6    predictor_5cb3fa02_5.parquet
# 7   predictor_5cb3fa02_10.parquet
# 8    predictor_5cb3fa02_5.parquet
# 9    predictor_5cb3fa02_2.parquet
# 10   predictor_5cb3fa02_5.parquet
# 11   predictor_5cb3fa02_1.parquet
#
#                                               indices
# 0   fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 1   fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 2   fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 3   fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 4   fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 5   fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 6   fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 7   fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 8   fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 9   fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 10  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 11  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...

# %%
cv_r2_seasons = {}
cv_mape_seasons = {}
r2_seasons = {}
mape_seasons = {}
tscv_r2_seasons = {}
tscv_mape_seasons = {}
for i in range(13):
    results_season = results[results["season"]==i]
    cv_r2_seasons[i] = summarize_best_results_by_index(results_season, metadata, metric="r2",stage="CV" , top_n=1)
    tscv_r2_seasons[i] = summarize_best_results_by_index(results_season, metadata, metric="r2",stage="TSCV" , top_n=1)
    r2_seasons[i] = summarize_best_results_by_index(results_season, metadata, metric="r2",stage="prediction", top_n=1)
    mape_seasons[i] = summarize_best_results_by_index(results_season, metadata, metric="mape",stage="prediction", top_n=1)
    cv_mape_seasons[i] = summarize_best_results_by_index(results_season, metadata, metric="mape",stage="CV", top_n=1)
    tscv_mape_seasons[i] = summarize_best_results_by_index(results_season, metadata, metric="mape",stage="TSCV", top_n=1)

cv_r2_seasons = pd.concat(list(cv_r2_seasons.values()))
cv_mape_seasons = pd.concat(list(cv_mape_seasons.values()))
tscv_r2_seasons = pd.concat(list(tscv_r2_seasons.values()))
tscv_mape_seasons = pd.concat(list(tscv_mape_seasons.values()))
r2_seasons = pd.concat(list(r2_seasons.values()))
mape_seasons = pd.concat(list(mape_seasons.values()))

# %%
display_full(tscv_r2_seasons)
# Out:
#        model    index  best_value   id_data                       filename
# 0    SLSTM16  Average        0.09  5cb3fa02   predictor_5cb3fa02_1.parquet  \
# 1      GRU16      HWA        0.15  5cb3fa02   predictor_5cb3fa02_1.parquet
# 2      RNN16      HWD        0.13  5cb3fa02   predictor_5cb3fa02_1.parquet
# 3      RNN16      HWF        0.24  5cb3fa02   predictor_5cb3fa02_1.parquet
# 4     SRNN16      HWM        0.12  5cb3fa02   predictor_5cb3fa02_1.parquet
# 5   CNNRNN16      HWN        0.30  5cb3fa02   predictor_5cb3fa02_1.parquet
# 0     LSTM16  Average        0.19  5cb3fa02   predictor_5cb3fa02_2.parquet
# 1   CNNRNN16      HWA        0.23  5cb3fa02   predictor_5cb3fa02_2.parquet
# 2   CNNRNN16      HWD        0.32  5cb3fa02   predictor_5cb3fa02_2.parquet
# 3     LSTM16      HWF        0.26  5cb3fa02   predictor_5cb3fa02_2.parquet
# 4     LSTM16      HWM        0.30  5cb3fa02   predictor_5cb3fa02_2.parquet
# 5     SRNN16      HWN        0.28  5cb3fa02   predictor_5cb3fa02_2.parquet
# 0  CNNLSTM16  Average       -0.78  5cb3fa02   predictor_5cb3fa02_3.parquet
# 1      GRU16      HWA       -0.03  5cb3fa02   predictor_5cb3fa02_3.parquet
# 2      GRU16      HWD       -0.47  5cb3fa02   predictor_5cb3fa02_3.parquet
# 3  CNNLSTM16      HWF       -0.52  6e47cb06   predictor_6e47cb06_3.parquet
# 4      GRU16      HWM        0.08  5cb3fa02   predictor_5cb3fa02_3.parquet
# 5      GRU16      HWN       -0.14  5cb3fa02   predictor_5cb3fa02_3.parquet
# 0    SLSTM16  Average       -0.06  5cb3fa02   predictor_5cb3fa02_4.parquet
# 1  CNNLSTM16      HWA       -0.06  5cb3fa02   predictor_5cb3fa02_4.parquet
# 2   CNNRNN16      HWD        0.01  5cb3fa02   predictor_5cb3fa02_4.parquet
# 3    SLSTM16      HWF        0.02  5cb3fa02   predictor_5cb3fa02_4.parquet
# 4    SLSTM16      HWM       -0.04  5cb3fa02   predictor_5cb3fa02_4.parquet
# 5     LSTM16      HWN        0.02  5cb3fa02   predictor_5cb3fa02_4.parquet
# 0     LSTM16  Average        0.29  5cb3fa02   predictor_5cb3fa02_5.parquet
# 1    SLSTM16      HWA        0.30  5cb3fa02   predictor_5cb3fa02_5.parquet
# 2     LSTM16      HWD        0.38  5cb3fa02   predictor_5cb3fa02_5.parquet
# 3     LSTM16      HWF        0.37  5cb3fa02   predictor_5cb3fa02_5.parquet
# 4    SLSTM16      HWM        0.30  5cb3fa02   predictor_5cb3fa02_5.parquet
# 5      GRU16      HWN        0.36  5cb3fa02   predictor_5cb3fa02_5.parquet
# 0     LSTM16  Average       -0.14  5cb3fa02   predictor_5cb3fa02_6.parquet
# 1      MLP16      HWA        0.10  6e47cb06   predictor_6e47cb06_6.parquet
# 2      RNN16      HWD        0.09  5cb3fa02   predictor_5cb3fa02_6.parquet
# 3     SRNN16      HWF       -0.32  5cb3fa02   predictor_5cb3fa02_6.parquet
# 4  CNNLSTM16      HWM       -0.01  5cb3fa02   predictor_5cb3fa02_6.parquet
# 5     LSTM16      HWN       -0.04  5cb3fa02   predictor_5cb3fa02_6.parquet
# 0     LSTM16  Average       -0.06  5cb3fa02   predictor_5cb3fa02_7.parquet
# 1      RNN16      HWA       -0.09  5cb3fa02   predictor_5cb3fa02_7.parquet
# 2      MLP16      HWD        0.02  6e47cb06   predictor_6e47cb06_7.parquet
# 3     LSTM16      HWF        0.03  5cb3fa02   predictor_5cb3fa02_7.parquet
# 4      RNN16      HWM        0.03  6e47cb06   predictor_6e47cb06_7.parquet
# 5      RNN16      HWN        0.07  5cb3fa02   predictor_5cb3fa02_7.parquet
# 0      GRU16  Average        0.01  6e47cb06   predictor_6e47cb06_8.parquet
# 1      MLP16      HWA        0.01  6e47cb06   predictor_6e47cb06_8.parquet
# 2      GRU16      HWD        0.05  6e47cb06   predictor_6e47cb06_8.parquet
# 3      MLP16      HWF        0.03  6e47cb06   predictor_6e47cb06_8.parquet
# 4      GRU16      HWM        0.01  6e47cb06   predictor_6e47cb06_8.parquet
# 5      GRU16      HWN        0.04  5cb3fa02   predictor_5cb3fa02_8.parquet
# 0     LSTM16  Average       -0.15  5cb3fa02   predictor_5cb3fa02_9.parquet
# 1     SRNN16      HWA       -0.05  6e47cb06   predictor_6e47cb06_9.parquet
# 2     LSTM16      HWD       -0.08  5cb3fa02   predictor_5cb3fa02_9.parquet
# 3      RNN16      HWF       -0.37  5cb3fa02   predictor_5cb3fa02_9.parquet
# 4     LSTM16      HWM        0.03  5cb3fa02   predictor_5cb3fa02_9.parquet
# 5     SRNN16      HWN       -0.17  6e47cb06   predictor_6e47cb06_9.parquet
# 0     SRNN16  Average        0.17  5cb3fa02  predictor_5cb3fa02_10.parquet
# 1   CNNRNN16      HWA        0.09  5cb3fa02  predictor_5cb3fa02_10.parquet
# 2     SRNN16      HWD        0.34  5cb3fa02  predictor_5cb3fa02_10.parquet
# 3      MLP16      HWF        0.30  5cb3fa02  predictor_5cb3fa02_10.parquet
# 4   CNNRNN16      HWM        0.21  5cb3fa02  predictor_5cb3fa02_10.parquet
# 5     SRNN16      HWN        0.19  5cb3fa02  predictor_5cb3fa02_10.parquet
# 0  CNNLSTM16  Average       -0.26  5cb3fa02  predictor_5cb3fa02_11.parquet
# 1     SRNN16      HWA       -0.22  5cb3fa02  predictor_5cb3fa02_11.parquet
# 2  CNNLSTM16      HWD       -0.16  5cb3fa02  predictor_5cb3fa02_11.parquet
# 3      MLP16      HWF       -0.13  5cb3fa02  predictor_5cb3fa02_11.parquet
# 4     SRNN16      HWM       -0.31  5cb3fa02  predictor_5cb3fa02_11.parquet
# 5  CNNLSTM16      HWN       -0.09  5cb3fa02  predictor_5cb3fa02_11.parquet
# 0  CNNLSTM16  Average       -1.23  6e47cb06  predictor_6e47cb06_12.parquet
# 1  CNNLSTM16      HWA       -0.94  6e47cb06  predictor_6e47cb06_12.parquet
# 2     LSTM16      HWD       -0.50  6e47cb06  predictor_6e47cb06_12.parquet
# 3     LSTM16      HWF       -0.55  5cb3fa02  predictor_5cb3fa02_12.parquet
# 4  CNNLSTM16      HWM       -1.94  5cb3fa02  predictor_5cb3fa02_12.parquet
# 5    SLSTM16      HWN       -0.70  5cb3fa02  predictor_5cb3fa02_12.parquet
#
#    season                                            indices
# 0       1  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 1       1  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 2       1  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 3       1  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 4       1  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 5       1  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 0       2  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 1       2  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 2       2  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 3       2  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 4       2  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 5       2  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 0       3  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 1       3  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 2       3  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 3       3  df9a31c5-20a07cea-cfb03125-9169e0dc-0b0bffae-b...
# 4       3  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 5       3  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 0       4  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 1       4  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 2       4  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 3       4  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 4       4  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 5       4  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 0       5  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 1       5  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 2       5  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 3       5  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 4       5  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 5       5  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 0       6  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 1       6  df9a31c5-20a07cea-cfb03125-9169e0dc-0b0bffae-b...
# 2       6  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 3       6  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 4       6  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 5       6  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 0       7  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 1       7  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 2       7  df9a31c5-20a07cea-cfb03125-9169e0dc-0b0bffae-b...
# 3       7  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 4       7  df9a31c5-20a07cea-cfb03125-9169e0dc-0b0bffae-b...
# 5       7  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 0       8  df9a31c5-20a07cea-cfb03125-9169e0dc-0b0bffae-b...
# 1       8  df9a31c5-20a07cea-cfb03125-9169e0dc-0b0bffae-b...
# 2       8  df9a31c5-20a07cea-cfb03125-9169e0dc-0b0bffae-b...
# 3       8  df9a31c5-20a07cea-cfb03125-9169e0dc-0b0bffae-b...
# 4       8  df9a31c5-20a07cea-cfb03125-9169e0dc-0b0bffae-b...
# 5       8  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 0       9  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 1       9  df9a31c5-20a07cea-cfb03125-9169e0dc-0b0bffae-b...
# 2       9  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 3       9  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 4       9  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 5       9  df9a31c5-20a07cea-cfb03125-9169e0dc-0b0bffae-b...
# 0      10  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 1      10  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 2      10  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 3      10  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 4      10  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 5      10  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 0      11  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 1      11  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 2      11  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 3      11  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 4      11  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 5      11  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 0      12  df9a31c5-20a07cea-cfb03125-9169e0dc-0b0bffae-b...
# 1      12  df9a31c5-20a07cea-cfb03125-9169e0dc-0b0bffae-b...
# 2      12  df9a31c5-20a07cea-cfb03125-9169e0dc-0b0bffae-b...
# 3      12  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 4      12  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...
# 5      12  fde0e327-340e2882-f27c56aa-5b9237bf-46fa0cb8-6...

# %% [markdown]
# ## Chile

# %%
region = "chile"
metadata_exp_path = f"data/climate_features/{region}/metadata.csv"
metadata = pd.read_csv(metadata_exp_path)
metadata.rename(columns={"id":"id_data"}, inplace=True)
metadata
# Out:
#       id_data                       filename  season
# 0    978f49d7   predictor_978f49d7_1.parquet       1  \
# 1    978f49d7   predictor_978f49d7_2.parquet       2
# 2    978f49d7   predictor_978f49d7_3.parquet       3
# 3    978f49d7   predictor_978f49d7_4.parquet       4
# 4    978f49d7   predictor_978f49d7_5.parquet       5
# ..        ...                            ...     ...
# 247  458d357c   predictor_458d357c_8.parquet       8
# 248  458d357c   predictor_458d357c_9.parquet       9
# 249  458d357c  predictor_458d357c_10.parquet      10
# 250  458d357c  predictor_458d357c_11.parquet      11
# 251  458d357c  predictor_458d357c_12.parquet      12
#
#                                                indices
# 0    fde0e327-340e2882-43701738-e306f58b-e601b072-e...
# 1    fde0e327-340e2882-43701738-e306f58b-e601b072-e...
# 2    fde0e327-340e2882-43701738-e306f58b-e601b072-e...
# 3    fde0e327-340e2882-43701738-e306f58b-e601b072-e...
# 4    fde0e327-340e2882-43701738-e306f58b-e601b072-e...
# ..                                                 ...
# 247  32f131d2-69ffcfa8-4af95abb-4a86cb22-52eda853-3...
# 248  32f131d2-69ffcfa8-4af95abb-4a86cb22-52eda853-3...
# 249  32f131d2-69ffcfa8-4af95abb-4a86cb22-52eda853-3...
# 250  32f131d2-69ffcfa8-4af95abb-4a86cb22-52eda853-3...
# 251  32f131d2-69ffcfa8-4af95abb-4a86cb22-52eda853-3...
#
# [252 rows x 4 columns]

# %%
results = pd.read_csv(f"data/climate_results_NN/{region}_results/results.csv")
results
# Out:
#            model  season metric       stage       HWN       HWF       HWD
# 0          RNN16       1     r2  prediction -1.137981 -0.101467 -0.540862  \
# 1         LSTM16       1     r2  prediction -0.296615 -0.293727 -0.611602
# 2          GRU16       1     r2  prediction -0.451169 -0.875157 -0.520603
# 3         SRNN16       1     r2  prediction -1.121952 -0.590102  0.306276
# 4        SLSTM16       1     r2  prediction -0.134914 -0.415837 -0.338187
# ...          ...     ...    ...         ...       ...       ...       ...
# 14107     SRNN16      12    mae        TSCV  0.702118  0.575218  0.704677
# 14108    SLSTM16      12    mae        TSCV  0.732042  0.726959  0.763230
# 14109   CNNRNN16      12    mae        TSCV  0.553936  0.611771  0.560034
# 14110  CNNLSTM16      12    mae        TSCV  0.791487  0.808835  0.817128
# 14111      MLP16      12    mae        TSCV  0.678506  0.689965  0.873295
#
#             HWM       HWA   Average   id_data
# 0      0.004724 -1.245405 -0.604198  978f49d7
# 1     -0.136574  0.003455 -0.267013  978f49d7
# 2     -0.549754 -0.113211 -0.501979  978f49d7
# 3     -0.561515 -1.116073 -0.616674  978f49d7
# 4      0.019838 -0.104378 -0.194695  978f49d7
# ...         ...       ...       ...       ...
# 14107  0.457367  0.628156  0.613507  458d357c
# 14108  0.589607  0.621670  0.686702  458d357c
# 14109  0.485108  0.473428  0.536855  458d357c
# 14110  0.598808  0.677477  0.738747  458d357c
# 14111  0.496433  0.704728  0.688585  458d357c
#
# [14112 rows x 11 columns]

# %%
# Example usage
summary_r2 = summarize_best_results_by_index(results, metadata, metric="r2", top_n=2, stage="prediction")
summary_mape = summarize_best_results_by_index(results, metadata, metric="mape", top_n=1, stage="prediction")
summary_cv_r2 = summarize_best_results_by_index(results, metadata, metric="r2", top_n=1, stage="CV")
summary_cv_mape = summarize_best_results_by_index(results, metadata, metric="mape", top_n=1, stage="CV")
summary_tscv_r2 = summarize_best_results_by_index(results, metadata, metric="r2", top_n=5, stage="TSCV")
summary_tscv_mape = summarize_best_results_by_index(results, metadata, metric="mape", top_n=3, stage="TSCV")
summary_tscv_mae = summarize_best_results_by_index(results, metadata, metric="mae", top_n=3, stage="TSCV")

# %%
display_full(summary_tscv_mae)
# Out:
#         model  season   id_data    index  best_value
# 0       GRU16      12  50a3f070  Average        0.49  \
# 1       MLP16      12  511854f2  Average        0.51
# 2   CNNLSTM16      12  9bd58418  Average        0.51
# 3    CNNRNN16      12  9bd58418      HWA        0.41
# 4       RNN16      12  511854f2      HWA        0.42
# 5       GRU16      12  50a3f070      HWA        0.44
# 6    CNNRNN16       6  511854f2      HWD        0.44
# 7    CNNRNN16       2  4d17ba1a      HWD        0.47
# 8    CNNRNN16       7  511854f2      HWD        0.48
# 9      SRNN16       6  3832cbd6      HWF        0.45
# 10  CNNLSTM16       6  3adff093      HWF        0.45
# 11   CNNRNN16       6  30ab9bad      HWF        0.47
# 12      GRU16      12  50a3f070      HWM        0.40
# 13      RNN16      12  ecf2577f      HWM        0.41
# 14      MLP16      12  b33fc639      HWM        0.43
# 15     SRNN16       8  3df87a13      HWN        0.44
# 16      GRU16       8  8c95fd00      HWN        0.46
# 17   CNNRNN16       8  9f8163e4      HWN        0.46
#
#                          filename
# 0   predictor_50a3f070_12.parquet  \
# 1   predictor_511854f2_12.parquet
# 2   predictor_9bd58418_12.parquet
# 3   predictor_9bd58418_12.parquet
# 4   predictor_511854f2_12.parquet
# 5   predictor_50a3f070_12.parquet
# 6    predictor_511854f2_6.parquet
# 7    predictor_4d17ba1a_2.parquet
# 8    predictor_511854f2_7.parquet
# 9    predictor_3832cbd6_6.parquet
# 10   predictor_3adff093_6.parquet
# 11   predictor_30ab9bad_6.parquet
# 12  predictor_50a3f070_12.parquet
# 13  predictor_ecf2577f_12.parquet
# 14  predictor_b33fc639_12.parquet
# 15   predictor_3df87a13_8.parquet
# 16   predictor_8c95fd00_8.parquet
# 17   predictor_9f8163e4_8.parquet
#
#                                               indices
# 0   fde0e327-340e2882-b91ccd4e-c6184040-c1c59e4d-8...
# 1   fde0e327-340e2882-b91ccd4e-c6184040-c1c59e4d-8...
# 2   fde0e327-340e2882-b91ccd4e-c6184040-c1c59e4d-8...
# 3   fde0e327-340e2882-b91ccd4e-c6184040-c1c59e4d-8...
# 4   fde0e327-340e2882-b91ccd4e-c6184040-c1c59e4d-8...
# 5   fde0e327-340e2882-b91ccd4e-c6184040-c1c59e4d-8...
# 6   fde0e327-340e2882-b91ccd4e-c6184040-c1c59e4d-8...
# 7   fde0e327-340e2882-b91ccd4e-c6184040-c1c59e4d-8...
# 8   fde0e327-340e2882-b91ccd4e-c6184040-c1c59e4d-8...
# 9   fde0e327-340e2882-13e2f761-aa75d48e-2748fd3a-f...
# 10                                PDO-ONI-SAM-DMI-ADV
# 11  fde0e327-340e2882-880b8b63-aa75d48e-88249a81-f...
# 12  fde0e327-340e2882-b91ccd4e-c6184040-c1c59e4d-8...
# 13  1f3bbd82-aac61eb2-bf935817-80ce3764-d6188e35-7...
# 14  fde0e327-340e2882-b91ccd4e-c6184040-c1c59e4d-8...
# 15  fde0e327-340e2882-880b8b63-aa75d48e-88249a81-f...
# 16  fde0e327-340e2882-8c5bce37-880b8b63-aa75d48e-8...
# 17  fde0e327-340e2882-8c5bce37-880b8b63-c6b80290-3...

# %%
cv_r2_seasons = {}
cv_mape_seasons = {}
r2_seasons = {}
mape_seasons = {}
tscv_r2_seasons = {}
tscv_mape_seasons = {}
tscv_mae_seasons = {}

for i in range(13):
    results_season = results[results["season"]==i]
    cv_r2_seasons[i] = summarize_best_results_by_index(results_season, metadata, metric="r2",stage="CV" , top_n=1)
    tscv_r2_seasons[i] = summarize_best_results_by_index(results_season, metadata, metric="r2",stage="TSCV" , top_n=1)
    r2_seasons[i] = summarize_best_results_by_index(results_season, metadata, metric="r2",stage="prediction", top_n=1)
    mape_seasons[i] = summarize_best_results_by_index(results_season, metadata, metric="mape",stage="prediction", top_n=1)
    cv_mape_seasons[i] = summarize_best_results_by_index(results_season, metadata, metric="mape",stage="CV", top_n=1)
    tscv_mape_seasons[i] = summarize_best_results_by_index(results_season, metadata, metric="mape",stage="TSCV", top_n=1)
    tscv_mae_seasons[i] = summarize_best_results_by_index(results_season, metadata, metric="mape",stage="TSCV", top_n=1)

cv_r2_seasons = pd.concat(list(cv_r2_seasons.values()))
cv_mape_seasons = pd.concat(list(cv_mape_seasons.values()))
tscv_r2_seasons = pd.concat(list(tscv_r2_seasons.values()))
tscv_mape_seasons = pd.concat(list(tscv_mape_seasons.values()))
tscv_mae_seasons = pd.concat(list(tscv_mae_seasons.values()))

r2_seasons = pd.concat(list(r2_seasons.values()))
mape_seasons = pd.concat(list(mape_seasons.values()))

# %%
df = tscv_r2_seasons
display_full(df[df["best_value"] > 0])
# display_full(df)
# Out:
#        model    index  best_value   id_data                       filename
# 4      RNN16      HWM        0.05  69ae08a8   predictor_69ae08a8_1.parquet  \
# 1     SRNN16      HWA        0.12  3832cbd6   predictor_3832cbd6_2.parquet
# 2   CNNRNN16      HWD        0.12  4d17ba1a   predictor_4d17ba1a_2.parquet
# 4      MLP16      HWM        0.09  d7101242   predictor_d7101242_2.parquet
# 0     SRNN16  Average        0.16  3832cbd6   predictor_3832cbd6_3.parquet
# 1   CNNRNN16      HWA        0.30  d7101242   predictor_d7101242_3.parquet
# 2     SRNN16      HWD        0.39  d7101242   predictor_d7101242_3.parquet
# 3     SRNN16      HWF        0.25  3df87a13   predictor_3df87a13_3.parquet
# 4     SRNN16      HWM        0.32  3832cbd6   predictor_3832cbd6_3.parquet
# 5      RNN16      HWN        0.18  3832cbd6   predictor_3832cbd6_3.parquet
# 3   CNNRNN16      HWF        0.09  9f8163e4   predictor_9f8163e4_4.parquet
# 0   CNNRNN16  Average        0.09  3df87a13   predictor_3df87a13_5.parquet
# 1   CNNRNN16      HWA        0.13  3df87a13   predictor_3df87a13_5.parquet
# 2      RNN16      HWD        0.21  ecf2577f   predictor_ecf2577f_5.parquet
# 3   CNNRNN16      HWF        0.23  3df87a13   predictor_3df87a13_5.parquet
# 4   CNNRNN16      HWM        0.28  3832cbd6   predictor_3832cbd6_5.parquet
# 5      RNN16      HWN        0.25  3832cbd6   predictor_3832cbd6_5.parquet
# 1   CNNRNN16      HWA        0.05  69ae08a8   predictor_69ae08a8_6.parquet
# 2  CNNLSTM16      HWD        0.09  4d17ba1a   predictor_4d17ba1a_6.parquet
# 3   CNNRNN16      HWF        0.12  978f49d7   predictor_978f49d7_6.parquet
# 4   CNNRNN16      HWM        0.12  511854f2   predictor_511854f2_6.parquet
# 5     SRNN16      HWN        0.24  311dd366   predictor_311dd366_6.parquet
# 1      GRU16      HWA        0.13  1b939ac5   predictor_1b939ac5_7.parquet
# 2     LSTM16      HWD        0.01  8c95fd00   predictor_8c95fd00_7.parquet
# 3     LSTM16      HWF        0.02  8c95fd00   predictor_8c95fd00_7.parquet
# 4  CNNLSTM16      HWM        0.05  1b939ac5   predictor_1b939ac5_7.parquet
# 5     LSTM16      HWN        0.05  8c95fd00   predictor_8c95fd00_7.parquet
# 0    SLSTM16  Average        0.12  9bd58418   predictor_9bd58418_8.parquet
# 1      GRU16      HWA        0.32  d7101242   predictor_d7101242_8.parquet
# 2  CNNLSTM16      HWD        0.27  30ab9bad   predictor_30ab9bad_8.parquet
# 3      MLP16      HWF        0.39  1b939ac5   predictor_1b939ac5_8.parquet
# 4      GRU16      HWM        0.37  d7101242   predictor_d7101242_8.parquet
# 5      GRU16      HWN        0.29  8c95fd00   predictor_8c95fd00_8.parquet
# 1      MLP16      HWA        0.00  3832cbd6   predictor_3832cbd6_9.parquet
# 2      GRU16      HWD        0.07  30ab9bad   predictor_30ab9bad_9.parquet
# 5  CNNLSTM16      HWN        0.06  d7101242   predictor_d7101242_9.parquet
# 0     SRNN16  Average        0.07  3df87a13  predictor_3df87a13_10.parquet
# 1   CNNRNN16      HWA        0.29  3df87a13  predictor_3df87a13_10.parquet
# 2     SRNN16      HWD        0.26  d7101242  predictor_d7101242_10.parquet
# 3      RNN16      HWF        0.26  30ab9bad  predictor_30ab9bad_10.parquet
# 4      GRU16      HWM        0.11  3df87a13  predictor_3df87a13_10.parquet
# 5     SRNN16      HWN        0.39  3df87a13  predictor_3df87a13_10.parquet
# 2      RNN16      HWD        0.00  9f8163e4  predictor_9f8163e4_11.parquet
# 0      RNN16  Average        0.27  4effa258  predictor_4effa258_12.parquet
# 1   CNNRNN16      HWA        0.45  458d357c  predictor_458d357c_12.parquet
# 2      RNN16      HWD        0.30  69ae08a8  predictor_69ae08a8_12.parquet
# 3      RNN16      HWF        0.46  4effa258  predictor_4effa258_12.parquet
# 4     SRNN16      HWM        0.45  4effa258  predictor_4effa258_12.parquet
# 5      RNN16      HWN        0.45  4effa258  predictor_4effa258_12.parquet
#
#    season                                            indices
# 4       1  fde0e327-340e2882-b91ccd4e-c6184040-c1c59e4d-8...
# 1       2  fde0e327-340e2882-13e2f761-aa75d48e-2748fd3a-f...
# 2       2  fde0e327-340e2882-b91ccd4e-c6184040-c1c59e4d-8...
# 4       2  fde0e327-340e2882-13e2f761-aa75d48e-2748fd3a-f...
# 0       3  fde0e327-340e2882-13e2f761-aa75d48e-2748fd3a-f...
# 1       3  fde0e327-340e2882-13e2f761-aa75d48e-2748fd3a-f...
# 2       3  fde0e327-340e2882-13e2f761-aa75d48e-2748fd3a-f...
# 3       3  fde0e327-340e2882-880b8b63-aa75d48e-88249a81-f...
# 4       3  fde0e327-340e2882-13e2f761-aa75d48e-2748fd3a-f...
# 5       3  fde0e327-340e2882-13e2f761-aa75d48e-2748fd3a-f...
# 3       4  fde0e327-340e2882-8c5bce37-880b8b63-c6b80290-3...
# 0       5  fde0e327-340e2882-880b8b63-aa75d48e-88249a81-f...
# 1       5  fde0e327-340e2882-880b8b63-aa75d48e-88249a81-f...
# 2       5  1f3bbd82-aac61eb2-bf935817-80ce3764-d6188e35-7...
# 3       5  fde0e327-340e2882-880b8b63-aa75d48e-88249a81-f...
# 4       5  fde0e327-340e2882-13e2f761-aa75d48e-2748fd3a-f...
# 5       5  fde0e327-340e2882-13e2f761-aa75d48e-2748fd3a-f...
# 1       6  fde0e327-340e2882-b91ccd4e-c6184040-c1c59e4d-8...
# 2       6  fde0e327-340e2882-b91ccd4e-c6184040-c1c59e4d-8...
# 3       6  fde0e327-340e2882-43701738-e306f58b-e601b072-e...
# 4       6  fde0e327-340e2882-b91ccd4e-c6184040-c1c59e4d-8...
# 5       6  fde0e327-340e2882-8c5bce37-880b8b63-aa75d48e-8...
# 1       7  fde0e327-340e2882-b91ccd4e-c6184040-c1c59e4d-8...
# 2       7  fde0e327-340e2882-8c5bce37-880b8b63-aa75d48e-8...
# 3       7  fde0e327-340e2882-8c5bce37-880b8b63-aa75d48e-8...
# 4       7  fde0e327-340e2882-b91ccd4e-c6184040-c1c59e4d-8...
# 5       7  fde0e327-340e2882-8c5bce37-880b8b63-aa75d48e-8...
# 0       8  fde0e327-340e2882-b91ccd4e-c6184040-c1c59e4d-8...
# 1       8  fde0e327-340e2882-13e2f761-aa75d48e-2748fd3a-f...
# 2       8  fde0e327-340e2882-880b8b63-aa75d48e-88249a81-f...
# 3       8  fde0e327-340e2882-b91ccd4e-c6184040-c1c59e4d-8...
# 4       8  fde0e327-340e2882-13e2f761-aa75d48e-2748fd3a-f...
# 5       8  fde0e327-340e2882-8c5bce37-880b8b63-aa75d48e-8...
# 1       9  fde0e327-340e2882-13e2f761-aa75d48e-2748fd3a-f...
# 2       9  fde0e327-340e2882-880b8b63-aa75d48e-88249a81-f...
# 5       9  fde0e327-340e2882-13e2f761-aa75d48e-2748fd3a-f...
# 0      10  fde0e327-340e2882-880b8b63-aa75d48e-88249a81-f...
# 1      10  fde0e327-340e2882-880b8b63-aa75d48e-88249a81-f...
# 2      10  fde0e327-340e2882-13e2f761-aa75d48e-2748fd3a-f...
# 3      10  fde0e327-340e2882-880b8b63-aa75d48e-88249a81-f...
# 4      10  fde0e327-340e2882-880b8b63-aa75d48e-88249a81-f...
# 5      10  fde0e327-340e2882-880b8b63-aa75d48e-88249a81-f...
# 2      11  fde0e327-340e2882-8c5bce37-880b8b63-c6b80290-3...
# 0      12  fde0e327-340e2882-a5df415f-c6184040-c1c59e4d-8...
# 1      12  32f131d2-69ffcfa8-4af95abb-4a86cb22-52eda853-3...
# 2      12  fde0e327-340e2882-b91ccd4e-c6184040-c1c59e4d-8...
# 3      12  fde0e327-340e2882-a5df415f-c6184040-c1c59e4d-8...
# 4      12  fde0e327-340e2882-a5df415f-c6184040-c1c59e4d-8...
# 5      12  fde0e327-340e2882-a5df415f-c6184040-c1c59e4d-8...

# %%
df = tscv_mae_seasons
display_full(df[["model", "index", "best_value", "id_data", "season"]])
# display_full(df)
# Out:
#        model    index         best_value   id_data  season
# 0     LSTM16  Average               1.08  458d357c       1
# 1    SLSTM16      HWA               0.73  9bd58418       1
# 2   CNNRNN16      HWD               1.02  1b939ac5       1
# 3     LSTM16      HWF               0.75  311dd366       1
# 4     LSTM16      HWM               0.83  69ae08a8       1
# 5      RNN16      HWN               0.76  9f8163e4       1
# 0    SLSTM16  Average               0.96  8c95fd00       2
# 1     LSTM16      HWA               0.84  b33fc639       2
# 2   CNNRNN16      HWD               0.67  4d17ba1a       2
# 3     LSTM16      HWF               0.90  4d17ba1a       2
# 4      MLP16      HWM               0.66  4effa258       2
# 5  CNNLSTM16      HWN               0.87  50a3f070       2
# 0    SLSTM16  Average               1.00  13a24caf       3
# 1    SLSTM16      HWA               0.85  30ab9bad       3
# 2      GRU16      HWD               0.78  3df87a13       3
# 3  CNNLSTM16      HWF               0.83  50a3f070       3
# 4    SLSTM16      HWM               0.76  69ae08a8       3
# 5   CNNRNN16      HWN               0.70  b33fc639       3
# 0     LSTM16  Average               0.92  458d357c       4
# 1      MLP16      HWA               0.68  458d357c       4
# 2  CNNLSTM16      HWD               0.87  8c95fd00       4
# 3      MLP16      HWF               0.86  30ab9bad       4
# 4      GRU16      HWM               0.78  3df87a13       4
# 5  CNNLSTM16      HWN               0.88  511854f2       4
# 0     LSTM16  Average               1.10  13a24caf       5
# 1      GRU16      HWA               0.82  3adff093       5
# 2    SLSTM16      HWD               0.73  9bd58418       5
# 3    SLSTM16      HWF               0.75  30ab9bad       5
# 4     LSTM16      HWM               1.15  13a24caf       5
# 5      GRU16      HWN               0.72  311dd366       5
# 0    SLSTM16  Average               0.68  8359c65d       6
# 1  CNNLSTM16      HWA               0.56  311dd366       6
# 2  CNNLSTM16      HWD               0.58  3adff093       6
# 3    SLSTM16      HWF               0.67  8359c65d       6
# 4      MLP16      HWM               0.61  13a24caf       6
# 5   CNNRNN16      HWN               0.59  511854f2       6
# 0     LSTM16  Average               0.85  8c95fd00       7
# 1   CNNRNN16      HWA               0.67  8359c65d       7
# 2  CNNLSTM16      HWD               0.85  4effa258       7
# 3   CNNRNN16      HWF               0.75  3adff093       7
# 4      RNN16      HWM               0.65  ecf2577f       7
# 5      GRU16      HWN               0.76  69ae08a8       7
# 0      RNN16  Average  36,120,208,695.26  978f49d7       8
# 1     LSTM16      HWA               0.96  1b939ac5       8
# 2      RNN16      HWD               0.82  50a3f070       8
# 3      RNN16      HWF 180,601,043,463.91  978f49d7       8
# 4  CNNLSTM16      HWM               0.84  30ab9bad       8
# 5    SLSTM16      HWN               0.81  50a3f070       8
# 0     LSTM16  Average               0.96  3df87a13       9
# 1   CNNRNN16      HWA               0.84  d7101242       9
# 2      RNN16      HWD               0.82  458d357c       9
# 3      GRU16      HWF               0.87  9bd58418       9
# 4      MLP16      HWM               0.77  458d357c       9
# 5     LSTM16      HWN               0.90  30ab9bad       9
# 0    SLSTM16  Average               0.92  3adff093      10
# 1    SLSTM16      HWA               0.89  3832cbd6      10
# 2  CNNLSTM16      HWD               0.67  8c95fd00      10
# 3     LSTM16      HWF               0.80  50a3f070      10
# 4      MLP16      HWM               0.83  b33fc639      10
# 5   CNNRNN16      HWN               0.71  8359c65d      10
# 0      GRU16  Average               0.77  30ab9bad      11
# 1   CNNRNN16      HWA               0.60  9bd58418      11
# 2     SRNN16      HWD               0.73  4d17ba1a      11
# 3      MLP16      HWF               0.63  ecf2577f      11
# 4      GRU16      HWM               0.69  30ab9bad      11
# 5     SRNN16      HWN               0.68  50a3f070      11
# 0      MLP16  Average               0.91  b33fc639      12
# 1      MLP16      HWA               1.01  b33fc639      12
# 2      MLP16      HWD               0.72  4d17ba1a      12
# 3     SRNN16      HWF               0.64  8c95fd00      12
# 4     SRNN16      HWM               0.63  b33fc639      12
# 5     SRNN16      HWN               0.73  3df87a13      12
