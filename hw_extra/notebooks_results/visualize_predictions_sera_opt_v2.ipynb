# %% [markdown]
# # Visualize Prediction SERA MONTH v2 rel fn

# %% [markdown]
# ## Imports and Functions

# %%
import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, LSTM, Dense, Dropout, GRU, Conv1D, Flatten, Reshape

import os
import numpy as np
import sys
import tensorflow as tf
import random
import keras

SEED = 42

def set_seeds(seed=SEED):
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    tf.random.set_seed(seed)
    np.random.seed(seed)
    keras.utils.set_random_seed(seed)

def set_global_determinism(seed=SEED):
    set_seeds(seed=seed)

    os.environ['TF_DETERMINISTIC_OPS'] = '1'
    os.environ['TF_CUDNN_DETERMINISTIC'] = '1'
    
    tf.config.threading.set_inter_op_parallelism_threads(1)
    tf.config.threading.set_intra_op_parallelism_threads(1)

# Call the above function with seed value
set_global_determinism(seed=SEED)

# %%
# Add the folder to the Python path

os.chdir("../")
# change working directory to project's root path
print(os.getcwd())

FIRST_YEAR= 1972
FREQUENCY= "monthly"
# Out:
# c:\Users\marti\Desktop\data\hw_extra

# %%
folder_path = os.path.abspath("functions/") #INPUT_PATH)#'path_to_your_folder')  # Replace with the actual folder path
sys.path.insert(0, folder_path)

from Predictions import (
    PredictionExperiment,
    PredictionModel,
    get_info_experiment,
    SERA
)
# Out:
# c:\Users\marti\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
indices_of_interest = ["HWN", "HWF", "HWD", "HWM", "HWA"]
bounds_v2 = (-1.1692892810242344, -0.30647585455315646, 3.0, 6.499969486244418)
i_w = 0.3

# %% [markdown]
# ## Chile good predictions per season

# %%
region="chile"
metadata = pd.read_csv(f"data/climate_features/{region}/metadata.csv")
metadata.reset_index(inplace=True, drop=True)
display(metadata)
# Out:
#            id                       filename  season
# 0    978f49d7   predictor_978f49d7_1.parquet       1  \
# 1    978f49d7   predictor_978f49d7_2.parquet       2
# 2    978f49d7   predictor_978f49d7_3.parquet       3
# 3    978f49d7   predictor_978f49d7_4.parquet       4
# 4    978f49d7   predictor_978f49d7_5.parquet       5
# ..        ...                            ...     ...
# 247  458d357c   predictor_458d357c_8.parquet       8
# 248  458d357c   predictor_458d357c_9.parquet       9
# 249  458d357c  predictor_458d357c_10.parquet      10
# 250  458d357c  predictor_458d357c_11.parquet      11
# 251  458d357c  predictor_458d357c_12.parquet      12
#
#                                                indices
# 0    fde0e327-340e2882-43701738-e306f58b-e601b072-e...
# 1    fde0e327-340e2882-43701738-e306f58b-e601b072-e...
# 2    fde0e327-340e2882-43701738-e306f58b-e601b072-e...
# 3    fde0e327-340e2882-43701738-e306f58b-e601b072-e...
# 4    fde0e327-340e2882-43701738-e306f58b-e601b072-e...
# ..                                                 ...
# 247  32f131d2-69ffcfa8-4af95abb-4a86cb22-52eda853-3...
# 248  32f131d2-69ffcfa8-4af95abb-4a86cb22-52eda853-3...
# 249  32f131d2-69ffcfa8-4af95abb-4a86cb22-52eda853-3...
# 250  32f131d2-69ffcfa8-4af95abb-4a86cb22-52eda853-3...
# 251  32f131d2-69ffcfa8-4af95abb-4a86cb22-52eda853-3...
#
# [252 rows x 4 columns]

# %% [markdown]
# ### January

# %%
ids_to_execute = ["978f49d7"]
get_info_experiment(ids_to_execute[0], f"data/climate_features/{region}/metadata.csv", "data/my_indices/metadata.csv", "data/extra_indices/metadata.csv")
# Out:
#                         filename   method rolling variables
# id
# fde0e327  index_fde0e327.parquet     anom       1       SST  \
# 340e2882  index_340e2882.parquet     anom       1       SST
# 43701738  index_43701738.parquet     anom       1        SP
# e306f58b  index_e306f58b.parquet     anom       1        SP
# e601b072  index_e601b072.parquet     anom       1        SP
# ecaf68aa  index_ecaf68aa.parquet     anom       1        SP
# 711b08fc  index_711b08fc.parquet      max       1        SP
# 89595d7b  index_89595d7b.parquet     anom       1       U10
# PDO                      pdo.dat      EOF       1   SSTAnom
# ONI                      oni.txt     Anom       3       SST
# SAM                      sam.txt  DifAnom       1       SLP
# DMI                     dmi.data     Grad       1   SSTAnom
#
#                               boxes reference_period target_period
# id
# fde0e327               190|240|-5|5        1980-2010     1972-2022
# 340e2882              270|280|-10|0        1980-2010     1972-2022
# 43701738            282|290|-34|-30        1980-2010     1972-2022
# e306f58b            282|290|-38|-34        1980-2010     1972-2022
# e601b072            282|290|-43|-38        1980-2010     1972-2022
# ecaf68aa            282|290|-56|-43        1980-2010     1972-2022
# 711b08fc            220|280|-35|-10            NoRef     1972-2022
# 89595d7b            282|290|-37|-30        1980-2010     1972-2022
# PDO                   110|260|20|70          unknown     1972-2022
# ONI                    190|240|-5|5    30yearsliding     1972-2022
# SAM                     X|X|-65|-40        1981-2010     1972-2022
# DMI       50|70|-10|10;90|110|-10|0        1991-2020     1972-2022

# %%
k=0
season = 1
for id in ids_to_execute:
    k+=1
    print("Executing",id, "iter", k)
    data = pd.read_parquet(f"data/climate_features/{region}/predictor_{id}_{season}.parquet")
    model = Sequential([
    SimpleRNN(16, activation="tanh", input_shape=(1, len(data.columns) - len(indices_of_interest))),
    Dropout(0.1),  # Regularization
    Dense(8, activation="relu"),
    Dense(len(indices_of_interest))  # Predict 5 indices
    ])
    pred = PredictionModel(data, season, indices_of_interest, model, name_regressor="RNN16",loss_fn=SERA(bounds=bounds_v2,T=100,fn='piecewise2', initial_weight=0.3))
    pred.compile_keras_model(metrics='mae')
    y_train, y_pred_train = pred.train(5)
    # y_test, y_pred = pred.predict(5)
    # dates = pd.date_range(pd.to_datetime(f"1972-{season}"),periods=len(y_train) + len(y_test),freq=pd.offsets.YearBegin(1))
    # pred.plot_predictions(dates, 5, y_train, y_pred_train, y_test, y_pred)
    pred.timeseries_cross_validate(5, label_plot="HWA")
# Out:
# Executing 978f49d7 iter 1
# 2/2 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 2ms/step

# %% [markdown]
# ## December

# %%
ids_to_execute = ["ecf2577f"]
get_info_experiment(ids_to_execute[0], f"data/climate_features/{region}/metadata.csv", "data/my_indices/metadata.csv", "data/extra_indices/metadata.csv")
# Out:
#                         filename      method rolling            variables
# id
# 1f3bbd82  index_1f3bbd82.parquet    normdiff     MSL       vaguada|config  \
# aac61eb2  index_aac61eb2.parquet  normalized     ADV      268|283|-32|-20
# bf935817  index_bf935817.parquet  normalized     ADV      282|286|-42|-33
# 80ce3764  index_80ce3764.parquet     bloqueo   U|MSL  bloqueo|norte|boxes
# d6188e35  index_d6188e35.parquet     bloqueo   U|MSL    bloqueo|sur|boxes
# 74b64e71  index_74b64e71.parquet        anom       1                  SST
# e08793a9  index_e08793a9.parquet        anom       1                  SST
# 15f248b7  index_15f248b7.parquet        anom       1                    T
# f00694af  index_f00694af.parquet         max       1                  MSL
# PDO                      pdo.dat         EOF       1              SSTAnom
# ONI                      oni.txt        Anom       3                  SST
# SAM                      sam.txt     DifAnom       1                  SLP
# DMI                     dmi.data        Grad       1              SSTAnom
#
#                               boxes reference_period target_period
# id
# 1f3bbd82                      NoRef        1972-2022           NaN
# aac61eb2                  1972-2024        1972-2022           NaN
# bf935817                  1972-2024        1972-2022           NaN
# 80ce3764                  1980-2010        1972-2022           NaN
# d6188e35                  1980-2010        1972-2022           NaN
# 74b64e71              270|280|-10|0        1980-2010     1972-2022
# e08793a9               190|240|-5|5        1980-2010     1972-2022
# 15f248b7            286|288|-42|-33        1980-2010     1972-2022
# f00694af            260|284|-44|-17        1980-2010     1972-2022
# PDO                   110|260|20|70          unknown     1972-2022
# ONI                    190|240|-5|5    30yearsliding     1972-2022
# SAM                     X|X|-65|-40        1981-2010     1972-2022
# DMI       50|70|-10|10;90|110|-10|0        1991-2020     1972-2022

# %%
k=0
season = 1
for id in ids_to_execute:
    k+=1
    print("Executing",id, "iter", k)
    data = {season: pd.read_parquet(f"data/climate_features/{region}/predictor_{id}_{season}.parquet")}
    model = Sequential([
        Conv1D(16, kernel_size=1, activation="relu", input_shape=(1, len(data[season].columns) - len(indices_of_interest))),
        Reshape((1, 16)),  # Back to time dimension
        SimpleRNN(8, activation="tanh"),
        Dropout(0.1),
        Dense(len(indices_of_interest))
    ])
    experiment_1 = PredictionExperiment(data, indices_of_interest, [model], ["CNNRNN16"], 5, id, loss_fn=SERA(bounds=bounds,T=100))
    experiment_1.execute_experiment(label_plot="HWM")
# Out:
# Executing ecf2577f iter 1
# Train predicting  12 MLP16
# Epoch 1/200
# 6/6 [==============================] - 16s 625ms/step - loss: 13.3320 - val_loss: 23.2237
# Epoch 2/200
# 6/6 [==============================] - 0s 7ms/step - loss: 11.7721 - val_loss: 22.5021
# Epoch 3/200
# 6/6 [==============================] - 0s 8ms/step - loss: 11.9953 - val_loss: 21.7517
# Epoch 4/200
# 6/6 [==============================] - 0s 8ms/step - loss: 10.7866 - val_loss: 21.1039
# Epoch 5/200
# 6/6 [==============================] - 0s 8ms/step - loss: 10.9466 - val_loss: 20.5525
# Epoch 6/200
# 6/6 [==============================] - 0s 8ms/step - loss: 10.6586 - val_loss: 20.0016
# Epoch 7/200
# 6/6 [==============================] - 0s 8ms/step - loss: 10.9613 - val_loss: 19.4949
# Epoch 8/200
# 6/6 [==============================] - 0s 8ms/step - loss: 11.1807 - val_loss: 19.0712
# Epoch 9/200
# 6/6 [==============================] - 0s 8ms/step - loss: 9.9403 - val_loss: 18.6317
# Epoch 10/200
# 6/6 [==============================] - 0s 8ms/step - loss: 9.5787 - val_loss: 18.1674
# Epoch 11/200
# 6/6 [==============================] - 0s 8ms/step - loss: 8.7985 - val_loss: 17.8780
# Epoch 12/200
# 6/6 [==============================] - 0s 8ms/step - loss: 9.1883 - val_loss: 17.6461
# Epoch 13/200
# 6/6 [==============================] - 0s 8ms/step - loss: 9.1152 - val_loss: 17.1278
# Epoch 14/200
# 6/6 [==============================] - 0s 8ms/step - loss: 8.9566 - val_loss: 16.7090
# Epoch 15/200
# 6/6 [==============================] - 0s 8ms/step - loss: 9.2321 - val_loss: 16.3793
# Epoch 16/200
# 6/6 [==============================] - 0s 8ms/step - loss: 8.4984 - val_loss: 16.0782
# Epoch 17/200
# 6/6 [==============================] - 0s 8ms/step - loss: 8.5299 - val_loss: 15.8848
# Epoch 18/200
# 6/6 [==============================] - 0s 8ms/step - loss: 8.0580 - val_loss: 15.6815
# Epoch 19/200
# 6/6 [==============================] - 0s 7ms/step - loss: 8.3750 - val_loss: 15.4065
# Epoch 20/200
# 6/6 [==============================] - 0s 8ms/step - loss: 8.6167 - val_loss: 15.2454
# Epoch 21/200
# 6/6 [==============================] - 0s 7ms/step - loss: 7.7328 - val_loss: 15.0544
# Epoch 22/200
# 6/6 [==============================] - 0s 8ms/step - loss: 7.3209 - val_loss: 14.7391
# Epoch 23/200
# 6/6 [==============================] - 0s 7ms/step - loss: 8.3343 - val_loss: 14.5493
# Epoch 24/200
# 6/6 [==============================] - 0s 7ms/step - loss: 7.4572 - val_loss: 14.3545
# Epoch 25/200
# 6/6 [==============================] - 0s 8ms/step - loss: 7.5488 - val_loss: 14.1093
# Epoch 26/200
# 6/6 [==============================] - 0s 7ms/step - loss: 7.8375 - val_loss: 13.9482
# Epoch 27/200
# 6/6 [==============================] - 0s 7ms/step - loss: 7.7510 - val_loss: 13.7795
# Epoch 28/200
# 6/6 [==============================] - 0s 8ms/step - loss: 7.3542 - val_loss: 13.6590
# Epoch 29/200
# 6/6 [==============================] - 0s 8ms/step - loss: 7.9439 - val_loss: 13.4289
# Epoch 30/200
# 6/6 [==============================] - 0s 7ms/step - loss: 6.8562 - val_loss: 13.2504
# Epoch 31/200
# 6/6 [==============================] - 0s 8ms/step - loss: 6.8008 - val_loss: 13.0660
# Epoch 32/200
# 6/6 [==============================] - 0s 11ms/step - loss: 6.3948 - val_loss: 12.9206
# Epoch 33/200
# 6/6 [==============================] - 0s 8ms/step - loss: 7.1671 - val_loss: 12.7348
# Epoch 34/200
# 6/6 [==============================] - 0s 8ms/step - loss: 6.2628 - val_loss: 12.5607
# Epoch 35/200
# 6/6 [==============================] - 0s 8ms/step - loss: 5.9203 - val_loss: 12.4754
# Epoch 36/200
# 6/6 [==============================] - 0s 8ms/step - loss: 6.2622 - val_loss: 12.3943
# Epoch 37/200
# 6/6 [==============================] - 0s 8ms/step - loss: 5.6750 - val_loss: 12.2986
# Epoch 38/200
# 6/6 [==============================] - 0s 8ms/step - loss: 6.4042 - val_loss: 12.1574
# Epoch 39/200
# 6/6 [==============================] - 0s 8ms/step - loss: 5.6570 - val_loss: 12.0273
# Epoch 40/200
# 6/6 [==============================] - 0s 8ms/step - loss: 5.9907 - val_loss: 11.9140
# Epoch 41/200
# 6/6 [==============================] - 0s 8ms/step - loss: 6.4716 - val_loss: 11.8309
# Epoch 42/200
# 6/6 [==============================] - 0s 8ms/step - loss: 6.6170 - val_loss: 11.7372
# Epoch 43/200
# 6/6 [==============================] - 0s 7ms/step - loss: 5.5130 - val_loss: 11.6713
# Epoch 44/200
# 6/6 [==============================] - 0s 8ms/step - loss: 6.1612 - val_loss: 11.5954
# Epoch 45/200
# 6/6 [==============================] - 0s 8ms/step - loss: 5.3658 - val_loss: 11.5627
# Epoch 46/200
# 6/6 [==============================] - 0s 8ms/step - loss: 6.2351 - val_loss: 11.5025
# Epoch 47/200
# 6/6 [==============================] - 0s 8ms/step - loss: 5.6620 - val_loss: 11.4225
# Epoch 48/200
# 6/6 [==============================] - 0s 7ms/step - loss: 5.3471 - val_loss: 11.3088
# Epoch 49/200
# 6/6 [==============================] - 0s 8ms/step - loss: 4.8899 - val_loss: 11.2290
# Epoch 50/200
# 6/6 [==============================] - 0s 7ms/step - loss: 5.2819 - val_loss: 11.1553
# Epoch 51/200
# 6/6 [==============================] - 0s 7ms/step - loss: 5.0518 - val_loss: 11.1112
# Epoch 52/200
# 6/6 [==============================] - 0s 8ms/step - loss: 6.5071 - val_loss: 11.0368
# Epoch 53/200
# 6/6 [==============================] - 0s 8ms/step - loss: 5.7064 - val_loss: 10.9597
# Epoch 54/200
# 6/6 [==============================] - 0s 7ms/step - loss: 6.5105 - val_loss: 10.8703
# Epoch 55/200
# 6/6 [==============================] - 0s 8ms/step - loss: 5.6831 - val_loss: 10.8380
# Epoch 56/200
# 6/6 [==============================] - 0s 7ms/step - loss: 4.6926 - val_loss: 10.7836
# Epoch 57/200
# 6/6 [==============================] - 0s 7ms/step - loss: 5.4752 - val_loss: 10.7481
# Epoch 58/200
# 6/6 [==============================] - 0s 11ms/step - loss: 6.4468 - val_loss: 10.7256
# Epoch 59/200
# 6/6 [==============================] - 0s 8ms/step - loss: 4.1625 - val_loss: 10.6662
# Epoch 60/200
# 6/6 [==============================] - 0s 7ms/step - loss: 5.3126 - val_loss: 10.6070
# Epoch 61/200
# 6/6 [==============================] - 0s 8ms/step - loss: 4.8493 - val_loss: 10.5112
# Epoch 62/200
# 6/6 [==============================] - 0s 7ms/step - loss: 5.7897 - val_loss: 10.4371
# Epoch 63/200
# 6/6 [==============================] - 0s 7ms/step - loss: 6.0825 - val_loss: 10.3920
# Epoch 64/200
# 6/6 [==============================] - 0s 7ms/step - loss: 4.8590 - val_loss: 10.3389
# Epoch 65/200
# 6/6 [==============================] - 0s 8ms/step - loss: 4.5338 - val_loss: 10.2764
# Epoch 66/200
# 6/6 [==============================] - 0s 8ms/step - loss: 3.8220 - val_loss: 10.2191
# Epoch 67/200
# 6/6 [==============================] - 0s 8ms/step - loss: 4.4666 - val_loss: 10.1730
# Epoch 68/200
# 6/6 [==============================] - 0s 8ms/step - loss: 5.0377 - val_loss: 10.1032
# Epoch 69/200
# 6/6 [==============================] - 0s 7ms/step - loss: 4.0068 - val_loss: 9.9640
# Epoch 70/200
# 6/6 [==============================] - 0s 7ms/step - loss: 3.8619 - val_loss: 9.8632
# Epoch 71/200
# 6/6 [==============================] - 0s 8ms/step - loss: 3.6031 - val_loss: 9.8127
# Epoch 72/200
# 6/6 [==============================] - 0s 8ms/step - loss: 5.0018 - val_loss: 9.7916
# Epoch 73/200
# 6/6 [==============================] - 0s 7ms/step - loss: 4.5210 - val_loss: 9.7744
# Epoch 74/200
# 6/6 [==============================] - 0s 7ms/step - loss: 4.2168 - val_loss: 9.7784
# Epoch 75/200
# 6/6 [==============================] - 0s 7ms/step - loss: 4.0566 - val_loss: 9.7919
# Epoch 76/200
# 6/6 [==============================] - 0s 7ms/step - loss: 3.5927 - val_loss: 9.8201
# Epoch 77/200
# 6/6 [==============================] - 0s 7ms/step - loss: 3.5430 - val_loss: 9.8459
# Epoch 78/200
# 6/6 [==============================] - 0s 8ms/step - loss: 4.2015 - val_loss: 9.8233
# Epoch 79/200
# 6/6 [==============================] - 0s 7ms/step - loss: 3.7280 - val_loss: 9.8012
# Epoch 80/200
# 6/6 [==============================] - 0s 7ms/step - loss: 4.6958 - val_loss: 9.8078
# Epoch 81/200
# 6/6 [==============================] - 0s 7ms/step - loss: 3.0779 - val_loss: 9.7900
# Epoch 82/200
# 6/6 [==============================] - 0s 7ms/step - loss: 3.2306 - val_loss: 9.7967
# Epoch 83/200
# 6/6 [==============================] - 0s 7ms/step - loss: 3.6033 - val_loss: 9.7904
# 2/2 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 2ms/step
