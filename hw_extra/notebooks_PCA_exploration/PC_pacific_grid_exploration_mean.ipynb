# %% [markdown]
# # PC Pacific Grid Exploration vs Means in Chile/California

# %% [markdown]
# ## Imports and Functions

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
from sklearn.preprocessing import MinMaxScaler
import scipy as sp
import os
from matplotlib.colors import ListedColormap, BoundaryNorm

import sys
import seaborn as sns

# %%
# Add the folder to the Python path

os.chdir("../")
# change working directory to project's root path
print(os.getcwd())

folder_path = os.path.abspath("functions/") #INPUT_PATH)#'path_to_your_folder')  # Replace with the actual folder path
sys.path.insert(0, folder_path)
# Out:
# c:\Users\marti\Desktop\data\hw_extra

# %%
from IndexDrivers import (
    MultivariatePCA, 
    plot_hw_index,
    plot_hw_index_by_season,
    scatter_color_year,
    scatter_color_season
)

# %%
def df_to_series(dataframe, name_series, years=[1979,2023]):
    selected = dataframe[(dataframe["Year"]< years[1]) & (dataframe["Year"] > years[0])]
    df_melted = selected.melt(id_vars=['Year'], var_name='Month', value_name=name_series)
    df_melted["Month"] = pd.to_numeric(df_melted["Month"])
    df_melted = df_melted.sort_values(['Year','Month'])

    df_melted['Date'] = pd.to_datetime(df_melted[['Year', 'Month']].assign(DAY=1))
    df_melted.set_index('Date', inplace=True)

    return df_melted.drop(columns=["Year", "Month"])

def plot_corr(dataframe, cols):
    sns.heatmap(dataframe.corr()[cols], cmap="coolwarm", annot=True)
    plt.show()

# %%
ds_5means = xr.load_dataset("data/local_data/5means_world.nc")

# %% [markdown]
# ## PCA on separated boxes

# %%
fig, axs = plt.subplots(figsize=(12,8))
ds_5means.sel(latitude=slice(-60,60), longitude=slice(120,290)).sst.isel(time=0).plot(ax=axs)
for i in range(3):
    axs.axhline(-30+i*30, c="red")
axs.axvline(205, c="red")
plt.show()

# %%
boxes = {
    0: [120,205,30,60],
    1: [205,290,30,60],
    2: [120,205,0,30],
    3: [205,290,0,30],
    4: [120,205,-30,0],
    5: [205,290,-30,0],
    6: [120,205,-60,-30],
    7: [205,290,-60,-30]
}

# %%
grid_pca = {}
for num, box in boxes.items():
    grid_pca[num] = MultivariatePCA(ds_5means, 2, [1980,2022], box_limit=box)

# %% [markdown]
# ## Chile Central

# %%
statlist = [330007, 330020, 330030, 340031, 360011, 380013, 360019, 390006, 400009, 410005]

heatwaves = pd.DataFrame()
for stat in statlist:
    hwis = pd.read_csv(f"data/local_data/HWs_{stat}.csv")
    hwis["Date"] = pd.to_datetime(hwis["Date"],format='%Y-%m')
    hwis.set_index('Date', inplace=True)

    heatwaves = pd.concat([heatwaves, hwis], axis=1)

mean_df = pd.DataFrame(index=heatwaves.index.unique())

columns = ["HWN", "HWF", "HWD", "HWM", "HWA"]

for index in columns:
    mean_df[index] = heatwaves[index].mean(axis=1)

mean_df.to_csv("HWs_chile_central.csv")

hwis = mean_df.rolling(2).mean()

hwis = hwis[(hwis.index.year <= 2022) & (hwis.index.year >= 1980)]
for mode in range(grid_pca[0].n_modes):
    for num, pca in grid_pca.items():
        hwis[f"Box {num}-Mode {mode+1}"] = pca.get_index(mode+1, start_year=1980)

# %% [markdown]
# Lets plot the correlation betwween the indices and the modes for the full span time

# %%
corr = hwis.corr()[["HWN", "HWF", "HWD", "HWM", "HWA"]]
corr.style.background_gradient(cmap='coolwarm').format("{:.3f}")
# Out:
# <style type="text/css">
# #T_b39f4_row0_col0, #T_b39f4_row1_col1, #T_b39f4_row2_col2, #T_b39f4_row3_col3, #T_b39f4_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b39f4_row0_col1, #T_b39f4_row1_col0 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_b39f4_row0_col2, #T_b39f4_row2_col0 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_b39f4_row0_col3 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_b39f4_row0_col4, #T_b39f4_row2_col4, #T_b39f4_row4_col0, #T_b39f4_row4_col2 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_b39f4_row1_col2, #T_b39f4_row2_col1 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_b39f4_row1_col3, #T_b39f4_row3_col1 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_b39f4_row1_col4, #T_b39f4_row4_col1 {
#   background-color: #d1493f;
#   color: #f1f1f1;
# }
# #T_b39f4_row2_col3, #T_b39f4_row3_col2 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_b39f4_row3_col0 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_b39f4_row3_col4, #T_b39f4_row4_col3 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_b39f4_row5_col0, #T_b39f4_row5_col1 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_b39f4_row5_col2, #T_b39f4_row15_col1 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_b39f4_row5_col3, #T_b39f4_row16_col2, #T_b39f4_row16_col3 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_b39f4_row5_col4, #T_b39f4_row16_col0 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_b39f4_row6_col0 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_b39f4_row6_col1, #T_b39f4_row13_col1 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_b39f4_row6_col2, #T_b39f4_row7_col2, #T_b39f4_row13_col0 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_b39f4_row6_col3 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_b39f4_row6_col4, #T_b39f4_row7_col3, #T_b39f4_row14_col3 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_b39f4_row7_col0, #T_b39f4_row19_col2 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_b39f4_row7_col1, #T_b39f4_row9_col2, #T_b39f4_row17_col1 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_b39f4_row7_col4 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_b39f4_row8_col0, #T_b39f4_row13_col3, #T_b39f4_row14_col4 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_b39f4_row8_col1, #T_b39f4_row8_col2, #T_b39f4_row17_col0, #T_b39f4_row17_col2 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_b39f4_row8_col3, #T_b39f4_row8_col4, #T_b39f4_row19_col0, #T_b39f4_row19_col3, #T_b39f4_row20_col1 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_b39f4_row9_col0, #T_b39f4_row19_col1 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_b39f4_row9_col1, #T_b39f4_row20_col3 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_b39f4_row9_col3, #T_b39f4_row20_col2 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_b39f4_row9_col4 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_b39f4_row10_col0 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_b39f4_row10_col1 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_b39f4_row10_col2 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_b39f4_row10_col3 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_b39f4_row10_col4 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_b39f4_row11_col0, #T_b39f4_row12_col0 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_b39f4_row11_col1 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_b39f4_row11_col2, #T_b39f4_row19_col4, #T_b39f4_row20_col0, #T_b39f4_row20_col4 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_b39f4_row11_col3, #T_b39f4_row17_col4 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_b39f4_row11_col4 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_b39f4_row12_col1 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_b39f4_row12_col2 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_b39f4_row12_col3 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_b39f4_row12_col4 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_b39f4_row13_col2 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_b39f4_row13_col4 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_b39f4_row14_col0 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_b39f4_row14_col1 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_b39f4_row14_col2 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_b39f4_row15_col0, #T_b39f4_row15_col4 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_b39f4_row15_col2, #T_b39f4_row18_col0, #T_b39f4_row18_col1, #T_b39f4_row18_col2, #T_b39f4_row18_col3, #T_b39f4_row18_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_b39f4_row15_col3 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_b39f4_row16_col1 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_b39f4_row16_col4 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_b39f4_row17_col3 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b39f4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b39f4_level0_col0" class="col_heading level0 col0" >HWN</th>
#       <th id="T_b39f4_level0_col1" class="col_heading level0 col1" >HWF</th>
#       <th id="T_b39f4_level0_col2" class="col_heading level0 col2" >HWD</th>
#       <th id="T_b39f4_level0_col3" class="col_heading level0 col3" >HWM</th>
#       <th id="T_b39f4_level0_col4" class="col_heading level0 col4" >HWA</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b39f4_level0_row0" class="row_heading level0 row0" >HWN</th>
#       <td id="T_b39f4_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_b39f4_row0_col1" class="data row0 col1" >0.982</td>
#       <td id="T_b39f4_row0_col2" class="data row0 col2" >0.954</td>
#       <td id="T_b39f4_row0_col3" class="data row0 col3" >0.880</td>
#       <td id="T_b39f4_row0_col4" class="data row0 col4" >0.919</td>
#     </tr>
#     <tr>
#       <th id="T_b39f4_level0_row1" class="row_heading level0 row1" >HWF</th>
#       <td id="T_b39f4_row1_col0" class="data row1 col0" >0.982</td>
#       <td id="T_b39f4_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_b39f4_row1_col2" class="data row1 col2" >0.973</td>
#       <td id="T_b39f4_row1_col3" class="data row1 col3" >0.862</td>
#       <td id="T_b39f4_row1_col4" class="data row1 col4" >0.908</td>
#     </tr>
#     <tr>
#       <th id="T_b39f4_level0_row2" class="row_heading level0 row2" >HWD</th>
#       <td id="T_b39f4_row2_col0" class="data row2 col0" >0.954</td>
#       <td id="T_b39f4_row2_col1" class="data row2 col1" >0.973</td>
#       <td id="T_b39f4_row2_col2" class="data row2 col2" >1.000</td>
#       <td id="T_b39f4_row2_col3" class="data row2 col3" >0.895</td>
#       <td id="T_b39f4_row2_col4" class="data row2 col4" >0.921</td>
#     </tr>
#     <tr>
#       <th id="T_b39f4_level0_row3" class="row_heading level0 row3" >HWM</th>
#       <td id="T_b39f4_row3_col0" class="data row3 col0" >0.880</td>
#       <td id="T_b39f4_row3_col1" class="data row3 col1" >0.862</td>
#       <td id="T_b39f4_row3_col2" class="data row3 col2" >0.895</td>
#       <td id="T_b39f4_row3_col3" class="data row3 col3" >1.000</td>
#       <td id="T_b39f4_row3_col4" class="data row3 col4" >0.985</td>
#     </tr>
#     <tr>
#       <th id="T_b39f4_level0_row4" class="row_heading level0 row4" >HWA</th>
#       <td id="T_b39f4_row4_col0" class="data row4 col0" >0.919</td>
#       <td id="T_b39f4_row4_col1" class="data row4 col1" >0.908</td>
#       <td id="T_b39f4_row4_col2" class="data row4 col2" >0.921</td>
#       <td id="T_b39f4_row4_col3" class="data row4 col3" >0.985</td>
#       <td id="T_b39f4_row4_col4" class="data row4 col4" >1.000</td>
#     </tr>
#     <tr>
#       <th id="T_b39f4_level0_row5" class="row_heading level0 row5" >Box 0-Mode 1</th>
#       <td id="T_b39f4_row5_col0" class="data row5 col0" >-0.063</td>
#       <td id="T_b39f4_row5_col1" class="data row5 col1" >-0.057</td>
#       <td id="T_b39f4_row5_col2" class="data row5 col2" >-0.057</td>
#       <td id="T_b39f4_row5_col3" class="data row5 col3" >-0.037</td>
#       <td i

# %% [markdown]
# We can check the correlation separated by biseason now, it appears to increase in certain boxes/seasons.

# %%
fig, axs = plt.subplots(3,4, figsize=(25,18))

hwis = hwis[(hwis.index.year <= 2022) & (hwis.index.year >= 2000)]
colors = ["blue", "white", "red"]
cmap = ListedColormap(colors)

# Define boundaries and normalize color range
bounds = [-1, -0.5, 0.5, 1]
norm = BoundaryNorm(bounds, cmap.N)


for i in range(12):
    hwis_month = hwis[hwis.index.month==i+1]
    #for num, pca in grid_pca.items():
    #    hwis_month.loc[:, f"Box {num}-Mode 1"] = pca.get_index_by_season(i+1, 1, start_year=2000)
    sns.heatmap(hwis_month.corr(method='pearson')[["HWN", "HWF", "HWD", "HWM", "HWA"]][5:], annot=True, fmt=".2f", cmap=cmap, norm=norm, ax=axs.flatten()[i], vmax=1, vmin=-1)
    axs.flatten()[i].set_title(f"Season {i+1}")
fig.tight_layout(rect=[0, 0.03, 1, 0.95])  # otherwise the right y-label is slightly clipped
fig.suptitle(f"Boxes linear correlation per season on Central Chile")
plt.show()

# %%
fig, axs = plt.subplots(3,4, figsize=(25,18))

hwis = hwis[(hwis.index.year <= 2022) & (hwis.index.year >= 2000)]
colors = ["blue", "white", "red"]
cmap = ListedColormap(colors)

# Define boundaries and normalize color range
bounds = [-1, -0.5, 0.5, 1]
norm = BoundaryNorm(bounds, cmap.N)


for i in range(12):
    hwis_month = hwis[hwis.index.month==i+1]
    #for num, pca in grid_pca.items():
    #    hwis_month.loc[:, f"Box {num}-Mode 1"] = pca.get_index_by_season(i+1, 1, start_year=2000)
    sns.heatmap(hwis_month.corr(method='spearman')[["HWN", "HWF", "HWD", "HWM", "HWA"]][5:], annot=True, fmt=".2f", cmap=cmap, norm=norm, ax=axs.flatten()[i], vmax=1, vmin=-1)
    axs.flatten()[i].set_title(f"Season {i+1}")
fig.tight_layout(rect=[0, 0.03, 1, 0.95])  # otherwise the right y-label is slightly clipped
fig.suptitle(f"Boxes Spearman correlation per season on Central Chile")
plt.show()

# %%
fig, axs = plt.subplots(3,4, figsize=(25,18))

hwis = hwis[(hwis.index.year <= 2022) & (hwis.index.year >= 2000)]
colors = ["blue", "white", "red"]
cmap = ListedColormap(colors)

# Define boundaries and normalize color range
bounds = [-1, -0.5, 0.5, 1]
norm = BoundaryNorm(bounds, cmap.N)


for i in range(12):
    hwis_month = hwis[hwis.index.month==i+1]
    #for num, pca in grid_pca.items():
    #    hwis_month.loc[:, f"Box {num}-Mode 1"] = pca.get_index_by_season(i+1, 1, start_year=2000)
    sns.heatmap(hwis_month.corr(method='kendall')[["HWN", "HWF", "HWD", "HWM", "HWA"]][5:], annot=True, fmt=".2f", cmap=cmap, norm=norm, ax=axs.flatten()[i], vmax=1, vmin=-1)
    axs.flatten()[i].set_title(f"Season {i+1}")
fig.tight_layout(rect=[0, 0.03, 1, 0.95])  # otherwise the right y-label is slightly clipped
fig.suptitle(f"Boxes Kendall Tau correlation per season on Central Chile")
plt.show()

# %% [markdown]
# A good question is about shifted correlation. As we want to predict the HW indices based on past data, let's check the 1-season shifted correlation:

# %%
fig, axs = plt.subplots(3,4, figsize=(25,18))

hwis = hwis[(hwis.index.year <= 2022) & (hwis.index.year >= 2000)]
for i in range(12):
    hwis_month = hwis[hwis.index.month==i+1]
    for num, pca in grid_pca.items():
        if i!= 0:
            hwis_month.loc[:, f"Box {num}-Mode 1"] = pca.get_index_by_season(i, 1, start_year=2000)
        else:
            hwis_month.loc[:, f"Box {num}-Mode 1"] = pca.get_index_by_season(12, 1, start_year=2000)
    sns.heatmap(hwis_month.corr()[["HWN", "HWF", "HWD", "HWM", "HWA"]][5:], annot=True, fmt=".2f", cmap=cmap, norm=norm, ax=axs.flatten()[i], vmax=1, vmin=-1)
    axs.flatten()[i].set_title(f"Season {i+1}")
fig.tight_layout(rect=[0, 0.03, 1, 0.95])  # otherwise the right y-label is slightly clipped
fig.suptitle(f"Boxes shifted correlation per season on Central Chile")
plt.show()

# %% [markdown]
# ### California

# %%
statlist_sorted = [5, 6, 35, 39, 43, 47, 52, 62, 70, 90] #sorted from N to S

heatwaves = pd.DataFrame()
for stat in statlist_sorted:
    hwis = pd.read_csv(f"data/local_data/HWs_{stat}.csv")
    hwis["Date"] = pd.to_datetime(hwis["Date"],format='%Y-%m')
    hwis.set_index('Date', inplace=True)

    heatwaves = pd.concat([heatwaves, hwis], axis=1)

mean_df = pd.DataFrame(index=heatwaves.index.unique())

columns = ["HWN", "HWF", "HWD", "HWM", "HWA"]

for index in columns:
    mean_df[index] = heatwaves[index].mean(axis=1)

mean_df.to_csv("HW_california.csv")

hwis = mean_df.rolling(2).mean()
hwis = hwis[(hwis.index.year <= 2022) & (hwis.index.year >= 1990)]

for mode in range(grid_pca[0].n_modes):
    for num, pca in grid_pca.items():
        hwis[f"Box {num}-Mode {mode+1}"] = pca.get_index(mode+1, start_year=1990)

# %% [markdown]
# Lets plot the correlation betwween the indices and the modes for the full span time

# %%
corr = hwis.corr()[["HWN", "HWF", "HWD", "HWM", "HWA"]]
corr.style.background_gradient(cmap='coolwarm').format("{:.3f}")
# Out:
# <style type="text/css">
# #T_b6cc2_row0_col0, #T_b6cc2_row1_col1, #T_b6cc2_row2_col2, #T_b6cc2_row3_col3, #T_b6cc2_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b6cc2_row0_col1, #T_b6cc2_row1_col0 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_b6cc2_row0_col2, #T_b6cc2_row1_col4, #T_b6cc2_row2_col0, #T_b6cc2_row2_col3, #T_b6cc2_row4_col1 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_b6cc2_row0_col3, #T_b6cc2_row3_col0 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# #T_b6cc2_row0_col4, #T_b6cc2_row3_col2 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_b6cc2_row1_col2, #T_b6cc2_row2_col1 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_b6cc2_row1_col3 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_b6cc2_row2_col4, #T_b6cc2_row4_col2 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_b6cc2_row3_col1 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_b6cc2_row3_col4, #T_b6cc2_row4_col3 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_b6cc2_row4_col0 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_b6cc2_row5_col0 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_b6cc2_row5_col1 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_b6cc2_row5_col2, #T_b6cc2_row11_col2 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_b6cc2_row5_col3, #T_b6cc2_row11_col3 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_b6cc2_row5_col4, #T_b6cc2_row17_col1 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_b6cc2_row6_col0 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_b6cc2_row6_col1, #T_b6cc2_row17_col4 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_b6cc2_row6_col2, #T_b6cc2_row7_col0 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_b6cc2_row6_col3, #T_b6cc2_row6_col4 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_b6cc2_row7_col1 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_b6cc2_row7_col2 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_b6cc2_row7_col3, #T_b6cc2_row8_col2, #T_b6cc2_row13_col0, #T_b6cc2_row13_col1 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_b6cc2_row7_col4, #T_b6cc2_row8_col0 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_b6cc2_row8_col1 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_b6cc2_row8_col3, #T_b6cc2_row9_col2, #T_b6cc2_row10_col1, #T_b6cc2_row12_col1 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_b6cc2_row8_col4 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_b6cc2_row9_col0, #T_b6cc2_row19_col3, #T_b6cc2_row19_col4 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_b6cc2_row9_col1 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_b6cc2_row9_col3, #T_b6cc2_row10_col4 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_b6cc2_row9_col4, #T_b6cc2_row10_col0, #T_b6cc2_row13_col3 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_b6cc2_row10_col2, #T_b6cc2_row12_col2, #T_b6cc2_row18_col0 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_b6cc2_row10_col3 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_b6cc2_row11_col0 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_b6cc2_row11_col1 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_b6cc2_row11_col4, #T_b6cc2_row14_col3 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_b6cc2_row12_col0 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_b6cc2_row12_col3 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_b6cc2_row12_col4, #T_b6cc2_row20_col1, #T_b6cc2_row20_col4 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_b6cc2_row13_col2, #T_b6cc2_row18_col4 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_b6cc2_row13_col4, #T_b6cc2_row18_col2 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_b6cc2_row14_col0, #T_b6cc2_row14_col2 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_b6cc2_row14_col1, #T_b6cc2_row17_col0 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_b6cc2_row14_col4, #T_b6cc2_row17_col2 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_b6cc2_row15_col0, #T_b6cc2_row18_col3 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_b6cc2_row15_col1 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_b6cc2_row15_col2 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_b6cc2_row15_col3 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_b6cc2_row15_col4 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_b6cc2_row16_col0, #T_b6cc2_row16_col1, #T_b6cc2_row16_col2, #T_b6cc2_row16_col3, #T_b6cc2_row16_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_b6cc2_row17_col3 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_b6cc2_row18_col1 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_b6cc2_row19_col0 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_b6cc2_row19_col1 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_b6cc2_row19_col2 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_b6cc2_row20_col0, #T_b6cc2_row20_col2 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_b6cc2_row20_col3 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b6cc2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b6cc2_level0_col0" class="col_heading level0 col0" >HWN</th>
#       <th id="T_b6cc2_level0_col1" class="col_heading level0 col1" >HWF</th>
#       <th id="T_b6cc2_level0_col2" class="col_heading level0 col2" >HWD</th>
#       <th id="T_b6cc2_level0_col3" class="col_heading level0 col3" >HWM</th>
#       <th id="T_b6cc2_level0_col4" class="col_heading level0 col4" >HWA</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b6cc2_level0_row0" class="row_heading level0 row0" >HWN</th>
#       <td id="T_b6cc2_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_b6cc2_row0_col1" class="data row0 col1" >0.956</td>
#       <td id="T_b6cc2_row0_col2" class="data row0 col2" >0.913</td>
#       <td id="T_b6cc2_row0_col3" class="data row0 col3" >0.886</td>
#       <td id="T_b6cc2_row0_col4" class="data row0 col4" >0.922</td>
#     </tr>
#     <tr>
#       <th id="T_b6cc2_level0_row1" class="row_heading level0 row1" >HWF</th>
#       <td id="T_b6cc2_row1_col0" class="data row1 col0" >0.956</td>
#       <td id="T_b6cc2_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_b6cc2_row1_col2" class="data row1 col2" >0.968</td>
#       <td id="T_b6cc2_row1_col3" class="data row1 col3" >0.874</td>
#       <td id="T_b6cc2_row1_col4" class="data row1 col4" >0.915</td>
#     </tr>
#     <tr>
#       <th id="T_b6cc2_level0_row2" class="row_heading level0 row2" >HWD</th>
#       <td id="T_b6cc2_row2_col0" class="data row2 col0" >0.913</td>
#       <td id="T_b6cc2_row2_col1" class="data row2 col1" >0.968</td>
#       <td id="T_b6cc2_row2_col2" class="data row2 col2" >1.000</td>
#       <td id="T_b6cc2_row2_col3" class="data row2 col3" >0.918</td>
#       <td id="T_b6cc2_row2_col4" class="data row2 col4" >0.940</td>
#     </tr>
#     <tr>
#       <th id="T_b6cc2_level0_row3" class="row_heading level0 row3" >HWM</th>
#       <td id="T_b6cc2_row3_col0" class="data row3 col0" >0.886</td>
#       <td id="T_b6cc2_row3_col1" class="data row3 col1" >0.874</td>
#       <td id="T_b6cc2_row3_col2" class="data row3 col2" >0.918</td>
#       <td id="T_b6cc2_row3_col3" class="data row3 col3" >1.000</td>
#       <td id="T_b6cc2_row3_col4" class="data row3 col4" >0.989</td>
#     </tr>
#     <tr>
#       <th id="T_b6cc2_level0_row4" class="row_heading level0 row4" >HWA</th>
#       <td id="T_b6cc2_row4_col0" class="data row4 col0" >0.922</td>
#       <td id="T_b6cc2_row4_col1" class="data row4 col1" >0.915</td>
#       <td id="T_b6cc2_row4_col2" class="data row4 col2" >0.940</td>
#       <td id="T_b6cc2_row4_col3" class="data row4 col3" >0.989</td>
#       <td id="T_b6cc2_row4_col4" class="data row4 col4" >1.000</td>
#     </tr>
#     <tr>
#       <th id="T_b6cc2_level0_row5" class="row_heading level0 row5" >Box 0-Mode 1</th>
#       <td id="T_b6cc2_row5_col0" class="data row5 col0" >0.105</td>
#       <td id="T_b6cc2_row5_col1" class="data row5 col1" >0.135</td>
#       <td id="T_b6cc2_row5_col2" class="data row5 c

# %% [markdown]
# We can check the correlation separated by biseason now, it appears to increase in certain boxes/seasons.

# %%
fig, axs = plt.subplots(3,4, figsize=(25,18))

hwis = hwis[(hwis.index.year <= 2022) & (hwis.index.year >= 2000)]
for i in range(12):
    hwis_month = hwis[hwis.index.month==i+1]
    #for num, pca in grid_pca.items():
    #    hwis_month.loc[:, f"Box {num}-Mode 1"] = pca.get_index_by_season(i+1, 1, start_year=2000)
    sns.heatmap(hwis_month.corr()[["HWN", "HWF", "HWD", "HWM", "HWA"]][5:], annot=True, fmt=".2f", cmap=cmap, norm=norm, ax=axs.flatten()[i], vmax=1, vmin=-1)
    axs.flatten()[i].set_title(f"Season {i+1}")
fig.tight_layout(rect=[0, 0.03, 1, 0.95])  # otherwise the right y-label is slightly clipped
fig.suptitle(f"Boxes linear correlation per season on California")
plt.show()

# %%
fig, axs = plt.subplots(3,4, figsize=(25,18))

hwis = hwis[(hwis.index.year <= 2022) & (hwis.index.year >= 2000)]
for i in range(12):
    hwis_month = hwis[hwis.index.month==i+1]
    for num, pca in grid_pca.items():
        hwis_month.loc[:, f"Box {num}-Mode 1"] = pca.get_index_by_season(i+1, 1, start_year=2000)
    sns.heatmap(hwis_month.corr(method='spearman')[["HWN", "HWF", "HWD", "HWM", "HWA"]][5:], annot=True, fmt=".2f", cmap=cmap, norm=norm, ax=axs.flatten()[i], vmax=1, vmin=-1)
    axs.flatten()[i].set_title(f"Season {i+1}")
fig.tight_layout(rect=[0, 0.03, 1, 0.95])  # otherwise the right y-label is slightly clipped
fig.suptitle(f"Boxes Spearman correlation per season on California")
plt.show()

# %%
fig, axs = plt.subplots(3,4, figsize=(25,18))

hwis = hwis[(hwis.index.year <= 2022) & (hwis.index.year >= 2000)]
for i in range(12):
    hwis_month = hwis[hwis.index.month==i+1]
    for num, pca in grid_pca.items():
        hwis_month.loc[:, f"Box {num}-Mode 1"] = pca.get_index_by_season(i+1, 1, start_year=2000)
    sns.heatmap(hwis_month.corr(method='kendall')[["HWN", "HWF", "HWD", "HWM", "HWA"]][5:], annot=True, fmt=".2f", cmap=cmap, norm=norm, ax=axs.flatten()[i], vmax=1, vmin=-1)
    axs.flatten()[i].set_title(f"Season {i+1}")
fig.tight_layout(rect=[0, 0.03, 1, 0.95])  # otherwise the right y-label is slightly clipped
fig.suptitle(f"Boxes Kendall Tau correlation per season on California")
plt.show()

# %% [markdown]
# A good question is about shifted correlation. As we want to predict the HW indices based on past data, let's check the 1-season shifted correlation:

# %%
fig, axs = plt.subplots(3,4, figsize=(25,18))

hwis = hwis[(hwis.index.year <= 2022) & (hwis.index.year >= 2000)]
for i in range(12):
    hwis_month = hwis[hwis.index.month==i+1]
    for num, pca in grid_pca.items():
        if i!= 0:
            hwis_month.loc[:, f"Box {num}-Mode 1"] = pca.get_index_by_season(i, 1, start_year=2000)
        else:
            hwis_month.loc[:, f"Box {num}-Mode 1"] = pca.get_index_by_season(12, 1, start_year=2000)
    sns.heatmap(hwis_month.corr()[["HWN", "HWF", "HWD", "HWM", "HWA"]][5:], annot=True, fmt=".2f", cmap=cmap, norm=norm, ax=axs.flatten()[i], vmax=1, vmin=-1)
    axs.flatten()[i].set_title(f"Season {i+1}")
fig.tight_layout(rect=[0, 0.03, 1, 0.95])  # otherwise the right y-label is slightly clipped
fig.suptitle(f"Boxes shifted correlation per season on California")
plt.show()
