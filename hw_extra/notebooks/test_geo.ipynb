# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import scipy as sp
import os
from itertools import combinations

import sys
import seaborn as sns
import re
import pickle


# Add the folder to the Python path

os.chdir("../")
# change working directory to project's root path
print(os.getcwd())

folder_path = os.path.abspath("functions/") #INPUT_PATH)#'path_to_your_folder')  # Replace with the actual folder path
sys.path.insert(0, folder_path)
# Out:
# c:\Users\marti\Desktop\data\hw_extra

# %%
data_geo = xr.load_dataset("data/local_data/geo500_1991_1993.nc").drop_vars("number").squeeze(dim="pressure_level").drop_vars("pressure_level").sel(valid_time=slice("1992-01","1992-12")).rename({"valid_time":"time"}).resample(time="M").mean()
data_means = xr.load_dataset("data/local_data/5means_world.nc").sel(time=slice("1992-01","1992-12"))
data_3 = xr.load_dataset("data/local_data/UVOLR1992.nc").resample(time="M").mean()
# Out:
# <string>:6: FutureWarning: 'M' is deprecated and will be removed in a future version. Please use 'ME' instead of 'M'.
# <string>:6: FutureWarning: 'M' is deprecated and will be removed in a future version. Please use 'ME' instead of 'M'.

# %%
new_ds = xr.merge([data_3, data_geo])
new_ds
# Out:
# <xarray.Dataset> Size: 349MB
# Dimensions:    (time: 12, latitude: 721, longitude: 1440)
# Coordinates:
#   * longitude  (longitude) float32 6kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#   * latitude   (latitude) float32 3kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * time       (time) datetime64[ns] 96B 1992-01-31 1992-02-29 ... 1992-12-31
# Data variables:
#     u10        (time, latitude, longitude) float64 100MB 0.02757 ... 0.4886
#     v10        (time, latitude, longitude) float64 100MB -0.00446 ... 0.1513
#     mtnlwrf    (time, latitude, longitude) float64 100MB -166.9 ... -168.7
#     z          (time, latitude, longitude) float32 50MB 4.915e+04 ... 4.979e+04
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-06-06 00:42:04 GMT by grib_to_netcdf-2.28.1: /opt/ecmw...
