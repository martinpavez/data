# %% [markdown]
# # Linear Similarity

# %% [markdown]
# This notebooks explores the linear similarity (dot product) across different timestamps from the same variable with a configuration of the variable that relates highly to heatwaves (in the same timestamp).

# %%
import pandas as pd

import os
import numpy as np
import sys
import xarray as xr
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %%
# Add the folder to the Python path

os.chdir("../")
# change working directory to project's root path
print(os.getcwd())
folder_path = os.path.abspath("functions/") #INPUT_PATH)#'path_to_your_folder')  # Replace with the actual folder path
sys.path.insert(0, folder_path)

from IndexDrivers import calculate_anomalies, Index
# Out:
# c:\Users\marti\Desktop\data\hw_extra

# %%
high_hws_dates = ["2015-03-01", "2016-09-01", "1997-08-01", "2017-02-01", "2019-02-01", "2014-08-01"]
low_hws_date = ["2000-05-01", "1990-11-01", "2001-05-01", "1975-05-01"]
def is_month(month, n):
    return month == n
hws_dates = {1: ['2016-01-01', '2017-01-01', '2013-01-01'],
             2: ['2020-02-01', '2005-02-01', '2008-02-01'],
             3: ['2015-03-01', '2009-03-01', '2012-03-01'],
             4: ['2009-04-01', '2017-04-01', '2015-04-01'],
             5: ['2020-05-01', '1998-05-01', '2023-05-01'],
             6: ['1987-06-01', '2015-06-01', '1991-06-01'],
             7: ['2023-07-01', '2006-07-01', '1996-07-01'],
             8: ['1997-08-01', '2001-08-01', '2003-08-01'],
             9: ['2016-09-01', '2008-09-01', '1996-09-01'],
             10: ['1983-10-01', '1989-10-01', '2014-10-01'],
             11: ['2019-11-01', '2008-11-01', '2022-11-01'],
             12: ['2021-12-01', '2001-12-01', '2013-12-01']}

non_hws_dates = {1: ['1975-01-01', '1974-01-01', '1981-01-01'],
             2: ['1975-02-01', '1972-02-01', '1986-02-01'],
             3: ['1975-03-01', '1972-03-01', '1985-03-01'],
             4: ['1975-04-01', '1973-04-01', '2000-04-01'],
             5: ['2000-05-01', '2001-05-01', '1975-05-01'],
             6: ['2007-06-01', '1975-06-01', '2011-06-01'],
             7: ['1971-07-01', '2017-07-01', '2007-07-01'],
             8: ['2017-08-01', '2007-08-01', '1971-08-01'],
             9: ['2007-09-01', '1987-09-01', '2017-09-01'],
             10: ['2023-10-01', '2017-10-01', '1987-10-01'],
             11: ['1990-11-01', '2017-11-01', '1973-11-01'],
             12: ['1975-12-01', '1973-12-01', '1974-12-01']}

# %%
# data_850 = xr.load_dataset("data/local_data/3means_850hpa_east_pacific.nc")
data_msl = xr.load_dataset("data/local_data/MSLP_east_pacific.nc")
# data_single = xr.load_dataset("data/local_data/7means_east_pacific.nc")

# %% [markdown]
# ## Vaguada Index Attempt

# %%
normalized_msl = data_msl

# %%
boxes_chile_vaguada = {
    "b": [286, 288.5, -33, -28],
    "A_cl": [280, 286, -38,-30], #test bigger A boxes
    "A_arg": [291, 295, -38, -30]
}

fig, ax = plt.subplots(4, 3, figsize=(20, 18))

times = [f"{1990+c}-06" for c in range(12)]
for i, timestamp in enumerate(times):
    normalized_msl.sel(longitude=slice(250,310), latitude=slice(-45,-20), time=timestamp).msl.plot(ax=ax.flatten()[i])

    for box_id, coords in boxes_chile_vaguada.items():
        lon_min, lon_max, lat_min, lat_max = coords
        width = lon_max - lon_min
        height = lat_max - lat_min
        
        # Create rectangle patch
        rect = mpatches.Rectangle((lon_min, lat_min), width, height,
                                fill=False, edgecolor='red', linewidth=2)
        ax.flatten()[i].add_patch(rect)
        
        # Optionally add a label
        ax.flatten()[i].text(lon_min + width/2, lat_min + height/2, f"{box_id}", 
                ha='center', va='center', color='red')

plt.show()

# %% [markdown]
# Apparently June on years 1990, 1996, 1998 and 2001 have some sort of vaguada configuration. These are potential point references.

# %%
def vaguada_index(datamsl, box_low, boxes_high, normalized=False):
    b_ts = datamsl.sel(longitude=slice(box_low[0], box_low[1]), latitude=slice(box_low[2], box_low[3])).mean(dim=["longitude", "latitude"]).to_numpy()

    a_tss = [datamsl.sel(longitude=slice(box[0], box[1]), latitude=slice(box[2], box[3])).mean(dim=["longitude", "latitude"]).to_numpy() for box in boxes_high]

    A_ts = np.mean(a_tss, axis=0)
    if normalized:
        vec = A_ts - b_ts
        return (vec-np.mean(vec))/np.std(vec)
    return A_ts - b_ts

vag_index = vaguada_index(normalized_msl.msl, boxes_chile_vaguada["b"], [boxes_chile_vaguada["A_arg"], boxes_chile_vaguada["A_cl"]], normalized=True)

# %%
df = normalized_msl.msl.time.to_dataframe()
df["vag"] = vag_index
df.drop(columns="time",inplace=True)
df
# Out:
#                  vag
# time
# 1971-01-01 -0.604558
# 1971-02-01  0.337207
# 1971-03-01  0.594257
# 1971-04-01  1.736931
# 1971-05-01  0.452950
# ...              ...
# 2024-08-01  0.451397
# 2024-09-01 -1.268016
# 2024-10-01 -0.413394
# 2024-11-01 -1.082572
# 2024-12-01 -0.488461
#
# [648 rows x 1 columns]

# %%
fig, axs = plt.subplots(figsize=(15,8))
axs.plot(normalized_msl.time, vag_index, c="black")
for date in high_hws_dates:
    axs.axvline(pd.to_datetime(date), color="red", ls='--')
for date in low_hws_date:
    axs.axvline(pd.to_datetime(date), color="blue", ls='--')

# %%
timeserie_seasons = {}
seasons = {i: normalized_msl.sel(time=is_month(normalized_msl['time.month'], i)).msl for i in range(1,13)}
for season, datas in seasons.items():
    timeserie_seasons[season] = vaguada_index(datas, boxes_chile_vaguada["b"], [boxes_chile_vaguada["A_arg"], boxes_chile_vaguada["A_cl"]], normalized=True)

# %%
fig, axs = plt.subplots(3,4, figsize=(20,12))
for season, ts in timeserie_seasons.items():
    axs.flatten()[season-1].plot(seasons[season].time, ts, c="black")
    axs.flatten()[season-1].set_title(f"Season {season}")
for season, dates in hws_dates.items():
    for d in dates:
        axs.flatten()[season-1].axvline(pd.to_datetime(d), color="red", ls='--')
for season, dates in non_hws_dates.items():
    for d in dates:
        axs.flatten()[season-1].axvline(pd.to_datetime(d), color="blue", ls='--')

# %%
time_max = np.argpartition(vag_index, -4)[-4:]
time_max
# Out:
# array([ 91, 545, 400, 642], dtype=int64)

# %%
fig, ax = plt.subplots(2,2 , figsize=(18, 15))

for i, timestamp in enumerate(time_max):
    normalized_msl.sel(longitude=slice(250,310), latitude=slice(-45,-20)).isel(time=timestamp).msl.plot(ax=ax.flatten()[i])

    for box_id, coords in boxes_chile_vaguada.items():
        lon_min, lon_max, lat_min, lat_max = coords
        width = lon_max - lon_min
        height = lat_max - lat_min
        
        # Create rectangle patch
        rect = mpatches.Rectangle((lon_min, lat_min), width, height,
                                fill=False, edgecolor='red', linewidth=2)
        ax.flatten()[i].add_patch(rect)
        
        # Optionally add a label
        ax.flatten()[i].text(lon_min + width/2, lat_min + height/2, f"{box_id}", 
                ha='center', va='center', color='red')

plt.show()

# %%
df = data_msl.time.to_dataframe()

# %%
df["vaguada_index"] = vag_index
df = df.drop(columns="time")
df = df[(df.index.year >= 1971) & (df.index.year <=2022)]
df.index = df.index.to_numpy().astype('datetime64[M]')  # Set the index as first day of the month
df.index.name = "Date"
df
# Out:
#             vaguada_index
# Date
# 1971-01-01      -0.604558
# 1971-02-01       0.337207
# 1971-03-01       0.594257
# 1971-04-01       1.736931
# 1971-05-01       0.452950
# ...                   ...
# 2022-08-01       0.631826
# 2022-09-01       0.227184
# 2022-10-01      -0.133958
# 2022-11-01      -0.654061
# 2022-12-01      -0.666913
#
# [624 rows x 1 columns]

# %%
vaguada_index = Index(data_msl, ["MSL"], boxes_chile_vaguada["b"])
vaguada_index.set_index(df)

# %%
box = "vaguada|config"
data = f"normdiff,MSL,{box},NoRef,1971-2022"
vaguada_index.index_df_to_parquet(data, "data/my_indices/","data/my_indices/metadata.csv")
# Out:
# Saved
# '03a619b8'

# %% [markdown]
# ## Vaguada HW month Configuration

# %%
timestamp_hw = "2022-10"

# %%
boxes_chile_vaguada = {
    "b": [286, 288.5, -33, -28],
    "A_cl": [280, 286, -38,-30], #test bigger A boxes
    "A_arg": [291, 295, -38, -30]
}

fig, ax = plt.subplots(figsize=(12, 8))

normalized_msl.sel(longitude=slice(250,310), latitude=slice(-60,-20), time=timestamp_hw).msl.plot(ax=ax)

for box_id, coords in boxes_chile_vaguada.items():
    lon_min, lon_max, lat_min, lat_max = coords
    width = lon_max - lon_min
    height = lat_max - lat_min
    
    # Create rectangle patch
    rect = mpatches.Rectangle((lon_min, lat_min), width, height,
                             fill=False, edgecolor='red', linewidth=2)
    ax.add_patch(rect)
    
    # Optionally add a label
    ax.text(lon_min + width/2, lat_min + height/2, f"{box_id}", 
            ha='center', va='center', color='red')

plt.show()

# %%
data_msl.sel(time=timestamp_hw).msl.plot()

# %%
anomalies = normalized_msl
box = boxes_chile_vaguada["b"]
b_data = anomalies.sel(longitude=slice(box[0], box[1]), latitude=slice(box[2],box[3]))
box = boxes_chile_vaguada["A_cl"]
acl_data = anomalies.sel(longitude=slice(box[0], box[1]), latitude=slice(box[2],box[3]))
box = boxes_chile_vaguada["A_arg"]
aarg_data = anomalies.sel(longitude=slice(box[0], box[1]), latitude=slice(box[2],box[3]))

# %%
b = b_data.sel(time=timestamp_hw).msl.to_numpy().reshape(b_data.sizes["latitude"], b_data.sizes["longitude"])
acl = acl_data.sel(time=timestamp_hw).msl.to_numpy().reshape(acl_data.sizes["latitude"], acl_data.sizes["longitude"])
aarg = aarg_data.sel(time=timestamp_hw).msl.to_numpy().reshape(aarg_data.sizes["latitude"], aarg_data.sizes["longitude"])

# %%
vector_hw = np.concatenate([b.flatten(), acl.flatten(), aarg.flatten()])

# %%
timeserie_dot_vag = []
for time_element in data_msl.msl:
    box = boxes_chile_vaguada["b"]
    b_data = time_element.sel(longitude=slice(box[0], box[1]), latitude=slice(box[2],box[3]))
    box = boxes_chile_vaguada["A_cl"]
    acl_data = time_element.sel(longitude=slice(box[0], box[1]), latitude=slice(box[2],box[3]))
    box = boxes_chile_vaguada["A_arg"]
    aarg_data = time_element.sel(longitude=slice(box[0], box[1]), latitude=slice(box[2],box[3]))
    element = [data.to_numpy().reshape(data.sizes["latitude"], data.sizes["longitude"]) for data in [b_data, acl_data, aarg_data]]
    element = np.concatenate([el.flatten() for el in element])
    timeserie_dot_vag.append(np.dot(vector_hw, element))

# %%
high_hws_dates = ["2015-03-01", "2016-09-01", "1997-08-01", "2017-02-01", "2019-02-01", "2014-08-01"]
low_hws_date = ["2000-05-01", "1990-11-01", "2001-05-01", "1975-05-01"]

# %%
fig, axs = plt.subplots(figsize=(15,8))
axs.plot(data_msl.time, timeserie_dot_vag, c="black")
for date in high_hws_dates:
    axs.axvline(pd.to_datetime(date), color="red", ls='--')
for date in low_hws_date:
    axs.axvline(pd.to_datetime(date), color="blue", ls='--')

# %%
mslp_indices_era5 = [data_msl.sel(latitude=slice(box[2],box[3]),
                           longitude=slice(box[0], box[1])
                           ).msl.mean(dim=["latitude","longitude"]) for key,box in boxes_chile_vaguada.items()]

# %%
vaguada_era5 = mslp_indices_era5[0] - (mslp_indices_era5[1]+mslp_indices_era5[2])/2

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(25, 15))

index1_era5 = vaguada_era5
index2_era5 = timeserie_dot_vag
index3_era5 = vag_index

# Plot first series
ax1.plot(index1_era5.time, index1_era5, color='blue', label='Vag index')
ax1.set_ylabel('Pa', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

# Second Y-axis (right side)
ax2 = ax1.twinx()
ax2.plot(data_msl.time, index2_era5, color='green', label='Dot vag index')
ax2.set_ylabel('Pa', color='green')
ax2.tick_params(axis='y', labelcolor='green')

ax3 = ax1.twinx()
ax3.plot(data_msl.time, vag_index, color='red', label='Normalized vag index')
ax3.set_ylabel('Pa', color='red')
ax3.tick_params(axis='y', labelcolor='red')


corr = np.corrcoef(index1_era5, index2_era5)[0,1]
ax1.set_title(f"Vag vs dot index: {corr}")
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

# %%
hwis = pd.read_csv("data/local_data/monthly/HWs_chile_central.csv")
hwis["Date"] = pd.to_datetime(hwis["Date"],format='%Y-%m')
hwis.set_index('Date', inplace=True)
hwis
# Out:
#             HWN  HWF  HWD       HWM       HWA
# Date
# 1971-01-01  0.0  0.0  0.0  0.000000  0.000000
# 1971-02-01  0.1  0.4  0.4  0.151800  0.341942
# 1971-03-01  0.0  0.0  0.0  0.000000  0.000000
# 1971-04-01  0.2  0.6  0.6  0.588719  0.933822
# 1971-05-01  0.1  0.3  0.3  0.520371  0.865883
# ...         ...  ...  ...       ...       ...
# 2023-08-01  0.1  0.3  0.3  0.349259  0.520451
# 2023-09-01  0.0  0.0  0.0  0.000000  0.000000
# 2023-10-01  0.1  0.3  0.3  0.040896  0.055833
# 2023-11-01  0.0  0.0  0.0  0.000000  0.000000
# 2023-12-01  0.0  0.0  0.0  0.000000  0.000000
#
# [636 rows x 5 columns]

# %%
hwis["vag_index"] = index1_era5.sel(time=slice("1971-01", "2023-12"))
hwis["dot_vag_indxe"] = index2_era5[:-12]
hwis["norm_vag_index"] = index3_era5[:-12]
hwis
# Out:
#             HWN  HWF  HWD       HWM       HWA   vag_index  dot_vag_indxe
# Date
# 1971-01-01  0.0  0.0  0.0  0.000000  0.000000   67.718750   1.671928e+13  \
# 1971-02-01  0.1  0.4  0.4  0.151800  0.341942  -36.468750   1.672731e+13
# 1971-03-01  0.0  0.0  0.0  0.000000  0.000000  -64.906250   1.674181e+13
# 1971-04-01  0.2  0.6  0.6  0.588719  0.933822 -191.320312   1.678469e+13
# 1971-05-01  0.1  0.3  0.3  0.520371  0.865883  -49.273438   1.677507e+13
# ...         ...  ...  ...       ...       ...         ...            ...
# 2023-08-01  0.1  0.3  0.3  0.349259  0.520451   88.984375   1.676452e+13
# 2023-09-01  0.0  0.0  0.0  0.000000  0.000000   98.117188   1.677193e+13
# 2023-10-01  0.1  0.3  0.3  0.040896  0.055833   85.265625   1.677364e+13
# 2023-11-01  0.0  0.0  0.0  0.000000  0.000000  210.359375   1.673780e+13
# 2023-12-01  0.0  0.0  0.0  0.000000  0.000000   60.773438   1.673379e+13
#
#             norm_vag_index
# Date
# 1971-01-01       -0.604558
# 1971-02-01        0.337207
# 1971-03-01        0.594257
# 1971-04-01        1.736931
# 1971-05-01        0.452950
# ...                    ...
# 2023-08-01       -0.796780
# 2023-09-01       -0.879333
# 2023-10-01       -0.763166
# 2023-11-01       -1.893905
# 2023-12-01       -0.541778
#
# [636 rows x 8 columns]

# %%
hwis.corr().style.background_gradient(cmap='coolwarm').format("{:.3f}")
# Out:
# <style type="text/css">
# #T_1f039_row0_col0, #T_1f039_row1_col1, #T_1f039_row2_col2, #T_1f039_row3_col3, #T_1f039_row4_col4, #T_1f039_row5_col5, #T_1f039_row6_col6, #T_1f039_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_1f039_row0_col1 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_1f039_row0_col2, #T_1f039_row2_col0 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_1f039_row0_col3, #T_1f039_row3_col0, #T_1f039_row3_col2 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_1f039_row0_col4, #T_1f039_row4_col0 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_1f039_row0_col5, #T_1f039_row3_col5, #T_1f039_row4_col5 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_1f039_row0_col6 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_1f039_row0_col7, #T_1f039_row3_col7, #T_1f039_row4_col7 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_1f039_row1_col0 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_1f039_row1_col2, #T_1f039_row2_col1 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_1f039_row1_col3 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_1f039_row1_col4, #T_1f039_row4_col1 {
#   background-color: #d1493f;
#   color: #f1f1f1;
# }
# #T_1f039_row1_col5 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_1f039_row1_col6 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_1f039_row1_col7 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_1f039_row2_col3 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# #T_1f039_row2_col4 {
#   background-color: #cf453c;
#   color: #f1f1f1;
# }
# #T_1f039_row2_col5 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_1f039_row2_col6 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_1f039_row2_col7 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_1f039_row3_col1 {
#   background-color: #dc5d4a;
#   color: #f1f1f1;
# }
# #T_1f039_row3_col4, #T_1f039_row4_col3 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_1f039_row3_col6 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_1f039_row4_col2 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_1f039_row4_col6 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_1f039_row5_col0, #T_1f039_row5_col1, #T_1f039_row5_col2, #T_1f039_row5_col3, #T_1f039_row5_col4, #T_1f039_row5_col6, #T_1f039_row5_col7, #T_1f039_row7_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_1f039_row6_col0 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_1f039_row6_col1 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_1f039_row6_col2 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_1f039_row6_col3 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_1f039_row6_col4 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_1f039_row6_col5 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_1f039_row6_col7 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_1f039_row7_col0 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_1f039_row7_col1 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_1f039_row7_col2 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_1f039_row7_col3, #T_1f039_row7_col4 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_1f039_row7_col6 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# </style>
# <table id="T_1f039">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1f039_level0_col0" class="col_heading level0 col0" >HWN</th>
#       <th id="T_1f039_level0_col1" class="col_heading level0 col1" >HWF</th>
#       <th id="T_1f039_level0_col2" class="col_heading level0 col2" >HWD</th>
#       <th id="T_1f039_level0_col3" class="col_heading level0 col3" >HWM</th>
#       <th id="T_1f039_level0_col4" class="col_heading level0 col4" >HWA</th>
#       <th id="T_1f039_level0_col5" class="col_heading level0 col5" >vag_index</th>
#       <th id="T_1f039_level0_col6" class="col_heading level0 col6" >dot_vag_indxe</th>
#       <th id="T_1f039_level0_col7" class="col_heading level0 col7" >norm_vag_index</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1f039_level0_row0" class="row_heading level0 row0" >HWN</th>
#       <td id="T_1f039_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_1f039_row0_col1" class="data row0 col1" >0.975</td>
#       <td id="T_1f039_row0_col2" class="data row0 col2" >0.944</td>
#       <td id="T_1f039_row0_col3" class="data row0 col3" >0.879</td>
#       <td id="T_1f039_row0_col4" class="data row0 col4" >0.912</td>
#       <td id="T_1f039_row0_col5" class="data row0 col5" >-0.284</td>
#       <td id="T_1f039_row0_col6" class="data row0 col6" >-0.022</td>
#       <td id="T_1f039_row0_col7" class="data row0 col7" >0.284</td>
#     </tr>
#     <tr>
#       <th id="T_1f039_level0_row1" class="row_heading level0 row1" >HWF</th>
#       <td id="T_1f039_row1_col0" class="data row1 col0" >0.975</td>
#       <td id="T_1f039_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_1f039_row1_col2" class="data row1 col2" >0.969</td>
#       <td id="T_1f039_row1_col3" class="data row1 col3" >0.850</td>
#       <td id="T_1f039_row1_col4" class="data row1 col4" >0.892</td>
#       <td id="T_1f039_row1_col5" class="data row1 col5" >-0.256</td>
#       <td id="T_1f039_row1_col6" class="data row1 col6" >-0.056</td>
#       <td id="T_1f039_row1_col7" class="data row1 col7" >0.256</td>
#     </tr>
#     <tr>
#       <th id="T_1f039_level0_row2" class="row_heading level0 row2" >HWD</th>
#       <td id="T_1f039_row2_col0" class="data row2 col0" >0.944</td>
#       <td id="T_1f039_row2_col1" class="data row2 col1" >0.969</td>
#       <td id="T_1f039_row2_col2" class="data row2 col2" >1.000</td>
#       <td id="T_1f039_row2_col3" class="data row2 col3" >0.882</td>
#       <td id="T_1f039_row2_col4" class="data row2 col4" >0.901</td>
#       <td id="T_1f039_row2_col5" class="data row2 col5" >-0.246</td>
#       <td id="T_1f039_row2_col6" class="data row2 col6" >-0.031</td>
#       <td id="T_1f039_row2_col7" class="data row2 col7" >0.246</td>
#     </tr>
#     <tr>
#       <th id="T_1f039_level0_row3" class="row_heading level0 row3" >HWM</th>
#       <td id="T_1f039_row3_col0" class="data row3 col0" >0.879</td>
#       <td id="T_1f039_row3_col1" class="data row3 col1" >0.850</td>
#       <td id="T_1f039_row3_col2" class="data row3 col2" >0.882</td>
#       <td id="T_1f039_row3_col3" class="data row3 col3" >1.000</td>
#       <td id="T_1f039_row3_col4" class="data row3 col4" >0.982</td>
#       <td id="T_1f039_row3_col5" class="data row3 col5" >-0.283</td>
#       <td id="T_1f039_row3_col6" class="data row3 col6" >0.071</td>
#       <td id="T_1f039_row3_col7" class="data row3 col7" >0.283</td>
#     </tr>
#     <tr>
#       <th id="T_1f039_level0_row4" class="row_heading level0 row4" >HWA</th>
#       <td id="T_1f039_row4_col0" class="data row4 col0" >0.912</td>
#       <td id="T_1f039_row4_col1" class="data row4 col1" >0.892</td>
#       <td id="T_1f039_row4_col2" class="data row4 col2" >0.901</td>
#       <td id="T_1f039_row4_col3" class="data row4 col3" >0.982</td>
#       <td id="T_1f039_row4_col4" class="data row4 col4" >1.000</td>
#       <td id="T_1f039_row4_col5" class="data row4 col5" >-0.282</td>
#       <td id="T_1f039_row4_col6" class="data row4 col6" >0.046</td>
#       <td id="T_1f039_row4_col7" class="data row4 col7" >0.282</td>
#     </tr>
#     <tr>
#       <th id="T_1f039_level0_row5" class="row_heading level0 row5" >vag_index</th>
#       <td id="T_1f039_row5_col0" class="data row5 col0" >-0.284</td>
#       <td id="T_1f039_row5_col1" class="data row5 col1" >-0.256</td>
#       <td id="T_1f039_row5_col2" class="data row5 col2" >-0.246</td>
#       <td id="T_1f039_row5_col3" class="data row5 col3" >-0.283</td>
#       <td id="T_1f039_row5_col4" class="data row5 col4" >-0.282</td>
#       <td id="T_1f039_row5_col5" class="data row5 col5" >1.000</td>
#       <td id="T_1f039_row5_col6" class="data row5 col6" >-0.464</td>
#       <td id="T_1f039_row5_col7" class="data row5 col7" >-1.000</td>
#     </tr>
#     <tr>
#       <th id="T_1f039_level0_row6" class="row_heading level0 row6" >dot_vag_indxe</th>
#       <td id="T_1f039_row6_col0" class="data row6 col0" >-0.022</td>
